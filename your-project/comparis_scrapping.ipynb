# %% [markdown]
# # Web Scrapping Comparis

# %%
import os
import math
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
from getpass import getpass
import csv
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# %% [markdown]
# # 1. Get the links --> Runde 2 with selenium

# %%
wdpath = "chromedriver"
driver = webdriver.Chrome(wdpath)

# %%
## for page 1
#### change city
url="https://www.comparis.ch/immobilien/marktplatz/bern/wohnung/mieten?page=2"
driver.get(url)

# %%
driver.execute_script("document.body.style.zoom = '0.1'")

# %%
flats_link = driver.find_elements_by_class_name("excbu0j3")

# %%
flat_links = list(set([flats.get_attribute('href') for flats in flats_link]))
flat_links
# Out:
# ['',
#  'https://www.comparis.ch/immobilien/result/list?requestobject=%7B%22DealType%22%3A10%2C%22SiteId%22%3A0%2C%22RootPropertyTypes%22%3A%5B1%5D%2C%22PropertyTypes%22%3Anull%2C%22RoomsFrom%22%3A%223%22%2C%22RoomsTo%22%3A%223.5%22%2C%22FloorSearchType%22%3A0%2C%22LivingSpaceFrom%22%3Anull%2C%22LivingSpaceTo%22%3Anull%2C%22PriceFrom%22%3A%22500%22%2C%22PriceTo%22%3A%221300%22%2C%22ComparisPointsMin%22%3A0%2C%22AdAgeMax%22%3A0%2C%22AdAgeInHoursMax%22%3Anull%2C%22Keyword%22%3A%22%22%2C%22WithImagesOnly%22%3Afalse%2C%22WithPointsOnly%22%3Anull%2C%22Radius%22%3Anull%2C%22MinAvailableDate%22%3Anull%2C%22MinChangeDate%22%3A%221753-01-01T00%3A00%3A00%22%2C%22LocationSearchString%22%3A%22Bern%22%2C%22Sort%22%3A11%2C%22HasBalcony%22%3Afalse%2C%22HasTerrace%22%3Afalse%2C%22HasFireplace%22%3Afalse%2C%22HasDishwasher%22%3Afalse%2C%22HasWashingMachine%22%3Afalse%2C%22HasLift%22%3Afalse%2C%22HasParking%22%3Afalse%2C%22PetsAllowed%22%3Afalse%2C%22MinergieCertified%22%3Afalse%2C%22WheelchairAccessible%22%3Afalse%2C%22LowerLeftLatitude%22%3Anull%2C%22LowerLeftLongitude%22%3Anull%2C%22UpperRightLatitude%22%3Anull%2C%22UpperRightLongitude%22%3Anull%7D&sort=11',
#  'https://www.comparis.ch/immobilien/result/list?requestobject=%7B%22DealType%22%3A10%2C%22SiteId%22%3A0%2C%22RootPropertyTypes%22%3A%5B1%5D%2C%22PropertyTypes%22%3Anull%2C%22RoomsFrom%22%3A%222%22%2C%22RoomsTo%22%3A%222.5%22%2C%22FloorSearchType%22%3A0%2C%22LivingSpaceFrom%22%3Anull%2C%22LivingSpaceTo%22%3Anull%2C%22PriceFrom%22%3A%22500%22%2C%22PriceTo%22%3A%221300%22%2C%22ComparisPointsMin%22%3A0%2C%22AdAgeMax%22%3A0%2C%22AdAgeInHoursMax%22%3Anull%2C%22Keyword%22%3A%22%22%2C%22WithImagesOnly%22%3Afalse%2C%22WithPointsOnly%22%3Anull%2C%22Radius%22%3Anull%2C%22MinAvailableDate%22%3Anull%2C%22MinChangeDate%22%3A%221753-01-01T00%3A00%3A00%22%2C%22LocationSearchString%22%3A%22Bern%22%2C%22Sort%22%3A11%2C%22HasBalcony%22%3Afalse%2C%22HasTerrace%22%3Afalse%2C%22HasFireplace%22%3Afalse%2C%22HasDishwasher%22%3Afalse%2C%22HasWashingMachine%22%3Afalse%2C%22HasLift%22%3Afalse%2C%22HasParking%22%3Afalse%2C%22PetsAllowed%22%3Afalse%2C%22MinergieCertified%22%3Afalse%2C%22WheelchairAccessible%22%3Afalse%2C%22LowerLeftLatitude%22%3Anull%2C%22LowerLeftLongitude%22%3Anull%2C%22UpperRightLatitude%22%3Anull%2C%22UpperRightLongitude%22%3Anull%7D&sort=11',
#  'https://www.comparis.ch/immobilien/marktplatz/bern/wohnung/mieten?page=1',
#  'https://www.snapchat.com/add/comparis.ch',
#  'https://www.comparis.ch/immobilien/marktplatz/bern/wohnung/mieten?page=78',
#  'https://www.comparis.ch/immobilien/result/list?requestobject=%7B%22DealType%22%3A10%2C%22SiteId%22%3A0%2C%22RootPropertyTypes%22%3A%5B1%5D%2C%22PropertyTypes%22%3A%5B16%5D%2C%22RoomsFrom%22%3Anull%2C%22RoomsTo%22%3Anull%2C%22FloorSearchType%22%3A0%2C%22LivingSpaceFrom%22%3Anull%2C%22LivingSpaceTo%22%3Anull%2C%22PriceFrom%22%3A%22500%22%2C%22PriceTo%22%3A%221300%22%2C%22ComparisPointsMin%22%3A0%2C%22AdAgeMax%22%3A0%2C%22AdAgeInHoursMax%22%3Anull%2C%22Keyword%22%3A%22%22%2C%22WithImagesOnly%22%3Afalse%2C%22WithPointsOnly%22%3Anull%2C%22Radius%22%3Anull%2C%22MinAvailableDate%22%3Anull%2C%22MinChangeDate%22%3A%221753-01-01T00%3A00%3A00%22%2C%22LocationSearchString%22%3A%22Bern%22%2C%22Sort%22%3A11%2C%22HasBalcony%22%3Afalse%2C%22HasTerrace%22%3Afalse%2C%22HasFireplace%22%3Afalse%2C%22HasDishwasher%22%3Afalse%2C%22HasWashingMachine%22%3Afalse%2C%22HasLift%22%3Afalse%2C%22HasParking%22%3Afalse%2C%22PetsAllowed%22%3Afalse%2C%22MinergieCertified%22%3Afalse%2C%22WheelchairAccessible%22%3Afalse%2C%22LowerLeftLatitude%22%3Anull%2C%22LowerLeftLongitude%22%3Anull%2C%22UpperRightLatitude%22%3Anull%2C%22UpperRightLongitude%22%3Anull%7D&sort=11',
#  'https://www.comparis.ch/immobilien/result/list?requestobject=%7B%22DealType%22%3A10%2C%22SiteId%22%3A0%2C%22RootPropertyTypes%22%3A%5B1%5D%2C%22PropertyTypes%22%3Anull%2C%22RoomsFrom%22%3Anull%2C%22RoomsTo%22%3Anull%2C%22FloorSearchType%22%3A0%2C%22LivingSpaceFrom%22%3Anull%2C%22LivingSpaceTo%22%3Anull%2C%22PriceFrom%22%3A%22500%22%2C%22PriceTo%22%3A%221300%22%2C%22ComparisPointsMin%22%3A0%2C%22AdAgeMax%22%3A0%2C%22AdAgeInHoursMax%22%3Anull%2C%22Keyword%22%3A%22%22%2C%22WithImagesOnly%22%3Afalse%2C%22WithPointsOnly%22%3Anull%2C%22Radius%22%3Anull%2C%22MinAvailableDate%22%3Anull%2C%22MinChangeDate%22%3A%221753-01-01T00%3A00%3A00%22%2C%22LocationSearchString%22%3A%22Bern%22%2C%22Sort%22%3A11%2C%22HasBalcony%22%3Afalse%2C%22HasTerrace%22%3Afalse%2C%22HasFireplace%22%3Afalse%2C%22HasDishwasher%22%3Afalse%2C%22HasWashingMachine%22%3Afalse%2C%22HasLift%22%3Afalse%2C%22HasParking%22%3Afalse%2C%22PetsAllowed%22%3Afalse%2C%22MinergieCertified%22%3Afalse%2C%22WheelchairAccessible%22%3Afalse%2C%22LowerLeftLatitude%22%3Anull%2C%22LowerLeftLongitude%22%3Anull%2C%22UpperRightLatitude%22%3Anull%2C%22UpperRightLongitude%22%3Anull%7D&sort=11',
#  'https://www.comparis.ch/immobilien/result/list?requestobject=%7B%22DealType%22%3A10%2C%22SiteId%22%3A0%2C%22RootPropertyTypes%22%3A%5B1%5D%2C%22PropertyTypes%22%3Anull%2C%22RoomsFrom%22%3A%221%22%2C%22RoomsTo%22%3A%221.5%22%2C%22FloorSearchType%22%3A0%2C%22LivingSpaceFrom%22%3Anull%2C%22LivingSpaceTo%22%3Anull%2C%22PriceFrom%22%3A%22500%22%2C%22PriceTo%22%3A%221300%22%2C%22ComparisPointsMin%22%3A0%2C%22AdAgeMax%22%3A0%2C%22AdAgeInHoursMax%22%3Anull%2C%22Keyword%22%3A%22%22%2C%22WithImagesOnly%22%3Afalse%2C%22WithPointsOnly%22%3Anull%2C%22Radius%22%3Anull%2C%22MinAvailableDate%22%3Anull%2C%22MinChangeDate%22%3A%221753-01-01T00%3A00%3A00%22%2C%22LocationSearchString%22%3A%22Bern%22%2C%22Sort%22%3A11%2C%22HasBalcony%22%3Afalse%2C%22HasTerrace%22%3Afalse%2C%22HasFireplace%22%3Afalse%2C%22HasDishwasher%22%3Afalse%2C%22HasWashingMachine%22%3Afalse%2C%22HasLift%22%3Afalse%2C%22HasParking%22%3Afalse%2C%22PetsAllowed%22%3Afalse%2C%22MinergieCertified%22%3Afalse%2C%22WheelchairAccessible%22%3Afalse%2C%22LowerLeftLatitude%22%3Anull%2C%22LowerLeftLongitude%22%3Anull%2C%22UpperRightLatitude%22%3Anull%2C%22UpperRightLongitude%22%3Anull%7D&sort=11',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23016606',
#  'https://www.comparis.ch/ueber-comparis',
#  'https://www.comparis.ch/comparis/karriere/jobs',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23018295',
#  'https://www.comparis.ch/immobilien/marktplatz/bern/wohnung/mieten',
#  'https://twitter.com/comparis',
#  'https://www.comparis.ch/immobilien/marktplatz/bern/wohnung/mieten?page=5',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23014335',
#  'https://www.comparis.ch/immobilien/marktplatz/bern/kirchenfeld/wohnung/mieten',
#  'https://www.comparis.ch/wohnen',
#  'https://www.youtube.com/comparis',
#  'https://www.comparis.ch/comparis/newsletter/subscribe',
#  'https://www.comparis.ch/immobilien/result/list?requestobject=%7B%22DealType%22%3A10%2C%22SiteId%22%3A0%2C%22RootPropertyTypes%22%3A%5B3%5D%2C%22PropertyTypes%22%3A%5B%5D%2C%22RoomsFrom%22%3Anull%2C%22RoomsTo%22%3Anull%2C%22FloorSearchType%22%3A0%2C%22LivingSpaceFrom%22%3Anull%2C%22LivingSpaceTo%22%3Anull%2C%22PriceFrom%22%3A%22500%22%2C%22PriceTo%22%3A%221300%22%2C%22ComparisPointsMin%22%3A0%2C%22AdAgeMax%22%3A0%2C%22AdAgeInHoursMax%22%3Anull%2C%22Keyword%22%3A%22%22%2C%22WithImagesOnly%22%3Afalse%2C%22WithPointsOnly%22%3Anull%2C%22Radius%22%3Anull%2C%22MinAvailableDate%22%3Anull%2C%22MinChangeDate%22%3A%221753-01-01T00%3A00%3A00%22%2C%22LocationSearchString%22%3A%22Bern%22%2C%22Sort%22%3A11%2C%22HasBalcony%22%3Afalse%2C%22HasTerrace%22%3Afalse%2C%22HasFireplace%22%3Afalse%2C%22HasDishwasher%22%3Afalse%2C%22HasWashingMachine%22%3Afalse%2C%22HasLift%22%3Afalse%2C%22HasParking%22%3Afalse%2C%22PetsAllowed%22%3Afalse%2C%22MinergieCertified%22%3Afalse%2C%22WheelchairAccessible%22%3Afalse%2C%22LowerLeftLatitude%22%3Anull%2C%22LowerLeftLongitude%22%3Anull%2C%22UpperRightLatitude%22%3Anull%2C%22UpperRightLongitude%22%3Anull%7D&sort=11',
#  'https://www.comparis.ch/immobilien/marktplatz/bern/wohnung/mieten?page=3',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23014342',
#  'https://www.comparis.ch/comparis/info/privacy',
#  'https://www.comparis.ch/immobilien/result/favoritelist',
#  'https://www.comparis.ch/immobilien/result/list?requestobject=%7B%22DealType%22%3A10%2C%22SiteId%22%3A0%2C%22RootPropertyTypes%22%3A%5B1%5D%2C%22PropertyTypes%22%3Anull%2C%22RoomsFrom%22%3A%224%22%2C%22RoomsTo%22%3A%224.5%22%2C%22FloorSearchType%22%3A0%2C%22LivingSpaceFrom%22%3Anull%2C%22LivingSpaceTo%22%3Anull%2C%22PriceFrom%22%3A%22500%22%2C%22PriceTo%22%3A%221300%22%2C%22ComparisPointsMin%22%3A0%2C%22AdAgeMax%22%3A0%2C%22AdAgeInHoursMax%22%3Anull%2C%22Keyword%22%3A%22%22%2C%22WithImagesOnly%22%3Afalse%2C%22WithPointsOnly%22%3Anull%2C%22Radius%22%3Anull%2C%22MinAvailableDate%22%3Anull%2C%22MinChangeDate%22%3A%221753-01-01T00%3A00%3A00%22%2C%22LocationSearchString%22%3A%22Bern%22%2C%22Sort%22%3A11%2C%22HasBalcony%22%3Afalse%2C%22HasTerrace%22%3Afalse%2C%22HasFireplace%22%3Afalse%2C%22HasDishwasher%22%3Afalse%2C%22HasWashingMachine%22%3Afalse%2C%22HasLift%22%3Afalse%2C%22HasParking%22%3Afalse%2C%22PetsAllowed%22%3Afalse%2C%22MinergieCertified%22%3Afalse%2C%22WheelchairAccessible%22%3Afalse%2C%22LowerLeftLatitude%22%3Anull%2C%22LowerLeftLongitude%22%3Anull%2C%22UpperRightLatitude%22%3Anull%2C%22UpperRightLongitude%22%3Anull%7D&sort=11',
#  'https://www.comparis.ch/immobilien/result/list?requestobject=%7B%22DealType%22%3A10%2C%22SiteId%22%3A0%2C%22RootPropertyTypes%22%3A%5B2%5D%2C%22PropertyTypes%22%3A%5B%5D%2C%22RoomsFrom%22%3Anull%2C%22RoomsTo%22%3Anull%2C%22FloorSearchType%22%3A0%2C%22LivingSpaceFrom%22%3Anull%2C%22LivingSpaceTo%22%3Anull%2C%22PriceFrom%22%3A%22500%22%2C%22PriceTo%22%3A%221300%22%2C%22ComparisPointsMin%22%3A0%2C%22AdAgeMax%22%3A0%2C%22AdAgeInHoursMax%22%3Anull%2C%22Keyword%22%3A%22%22%2C%22WithImagesOnly%22%3Afalse%2C%22WithPointsOnly%22%3Anull%2C%22Radius%22%3Anull%2C%22MinAvailableDate%22%3Anull%2C%22MinChangeDate%22%3A%221753-01-01T00%3A00%3A00%22%2C%22LocationSearchString%22%3A%22Bern%22%2C%22Sort%22%3A11%2C%22HasBalcony%22%3Afalse%2C%22HasTerrace%22%3Afalse%2C%22HasFireplace%22%3Afalse%2C%22HasDishwasher%22%3Afalse%2C%22HasWashingMachine%22%3Afalse%2C%22HasLift%22%3Afalse%2C%22HasParking%22%3Afalse%2C%22PetsAllowed%22%3Afalse%2C%22MinergieCertified%22%3Afalse%2C%22WheelchairAccessible%22%3Afalse%2C%22LowerLeftLatitude%22%3Anull%2C%22LowerLeftLongitude%22%3Anull%2C%22UpperRightLatitude%22%3Anull%2C%22UpperRightLongitude%22%3Anull%7D&sort=11',
#  'https://www.comparis.ch/comparis/press/default',
#  'https://www.comparis.ch/',
#  'https://www.linkedin.com/company/comparis.ch-ag',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23014344',
#  'https://www.comparis.ch/immobilien/marktplatz/bern/lorraine/wohnung/mieten',
#  'https://www.comparis.ch/comparis/info/kontakt',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23016600',
#  'https://www.comparis.ch/immobilien/marktplatz/bern/wohnung/mieten?page=4',
#  'https://www.comparis.ch/comparis/info/legal',
#  'https://en.comparis.ch/immobilien/marktplatz/bern/wohnung/mieten?page=2',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23014346',
#  None,
#  'https://it.comparis.ch/immobilien/marktplatz/bern/wohnung/mieten?page=2',
#  'https://www.comparis.ch/Authentication/Login?successUrl=/immobilien/marktplatz/bern/wohnung/mieten',
#  'https://www.comparis.ch/immobilien/marktplatz/bern/wohnung/mieten?page=2',
#  'https://www.comparis.ch/immobilien/result/list?requestobject=%7B%22DealType%22%3A10%2C%22SiteId%22%3A0%2C%22RootPropertyTypes%22%3A%5B1%5D%2C%22PropertyTypes%22%3A%5B13%5D%2C%22RoomsFrom%22%3Anull%2C%22RoomsTo%22%3Anull%2C%22FloorSearchType%22%3A0%2C%22LivingSpaceFrom%22%3Anull%2C%22LivingSpaceTo%22%3Anull%2C%22PriceFrom%22%3A%22500%22%2C%22PriceTo%22%3A%221300%22%2C%22ComparisPointsMin%22%3A0%2C%22AdAgeMax%22%3A0%2C%22AdAgeInHoursMax%22%3Anull%2C%22Keyword%22%3A%22%22%2C%22WithImagesOnly%22%3Afalse%2C%22WithPointsOnly%22%3Anull%2C%22Radius%22%3Anull%2C%22MinAvailableDate%22%3Anull%2C%22MinChangeDate%22%3A%221753-01-01T00%3A00%3A00%22%2C%22LocationSearchString%22%3A%22Bern%22%2C%22Sort%22%3A11%2C%22HasBalcony%22%3Afalse%2C%22HasTerrace%22%3Afalse%2C%22HasFireplace%22%3Afalse%2C%22HasDishwasher%22%3Afalse%2C%22HasWashingMachine%22%3Afalse%2C%22HasLift%22%3Afalse%2C%22HasParking%22%3Afalse%2C%22PetsAllowed%22%3Afalse%2C%22MinergieCertified%22%3Afalse%2C%22WheelchairAccessible%22%3Afalse%2C%22LowerLeftLatitude%22%3Anull%2C%22LowerLeftLongitude%22%3Anull%2C%22UpperRightLatitude%22%3Anull%2C%22UpperRightLongitude%22%3Anull%7D&sort=11',
#  'https://www.facebook.com/comparis.ch',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23016559',
#  'https://www.comparis.ch/immobilien/result/list?requestobject=%7B%22DealType%22%3A10%2C%22SiteId%22%3A0%2C%22RootPropertyTypes%22%3A%5B1%5D%2C%22PropertyTypes%22%3A%5B17%5D%2C%22RoomsFrom%22%3Anull%2C%22RoomsTo%22%3Anull%2C%22FloorSearchType%22%3A0%2C%22LivingSpaceFrom%22%3Anull%2C%22LivingSpaceTo%22%3Anull%2C%22PriceFrom%22%3A%22500%22%2C%22PriceTo%22%3A%221300%22%2C%22ComparisPointsMin%22%3A0%2C%22AdAgeMax%22%3A0%2C%22AdAgeInHoursMax%22%3Anull%2C%22Keyword%22%3A%22%22%2C%22WithImagesOnly%22%3Afalse%2C%22WithPointsOnly%22%3Anull%2C%22Radius%22%3Anull%2C%22MinAvailableDate%22%3Anull%2C%22MinChangeDate%22%3A%221753-01-01T00%3A00%3A00%22%2C%22LocationSearchString%22%3A%22Bern%22%2C%22Sort%22%3A11%2C%22HasBalcony%22%3Afalse%2C%22HasTerrace%22%3Afalse%2C%22HasFireplace%22%3Afalse%2C%22HasDishwasher%22%3Afalse%2C%22HasWashingMachine%22%3Afalse%2C%22HasLift%22%3Afalse%2C%22HasParking%22%3Afalse%2C%22PetsAllowed%22%3Afalse%2C%22MinergieCertified%22%3Afalse%2C%22WheelchairAccessible%22%3Afalse%2C%22LowerLeftLatitude%22%3Anull%2C%22LowerLeftLongitude%22%3Anull%2C%22UpperRightLatitude%22%3Anull%2C%22UpperRightLongitude%22%3Anull%7D&sort=11',
#  'https://www.comparis.ch/comparis/press/impressum',
#  'https://www.comparis.ch/immobilien/result/list?requestobject=%7B%22DealType%22%3A10%2C%22SiteId%22%3A0%2C%22RootPropertyTypes%22%3A%5B26%5D%2C%22PropertyTypes%22%3A%5B%5D%2C%22RoomsFrom%22%3Anull%2C%22RoomsTo%22%3Anull%2C%22FloorSearchType%22%3A0%2C%22LivingSpaceFrom%22%3Anull%2C%22LivingSpaceTo%22%3Anull%2C%22PriceFrom%22%3A%22500%22%2C%22PriceTo%22%3A%221300%22%2C%22ComparisPointsMin%22%3A0%2C%22AdAgeMax%22%3A0%2C%22AdAgeInHoursMax%22%3Anull%2C%22Keyword%22%3A%22%22%2C%22WithImagesOnly%22%3Afalse%2C%22WithPointsOnly%22%3Anull%2C%22Radius%22%3Anull%2C%22MinAvailableDate%22%3Anull%2C%22MinChangeDate%22%3A%221753-01-01T00%3A00%3A00%22%2C%22LocationSearchString%22%3A%22Bern%22%2C%22Sort%22%3A11%2C%22HasBalcony%22%3Afalse%2C%22HasTerrace%22%3Afalse%2C%22HasFireplace%22%3Afalse%2C%22HasDishwasher%22%3Afalse%2C%22HasWashingMachine%22%3Afalse%2C%22HasLift%22%3Afalse%2C%22HasParking%22%3Afalse%2C%22PetsAllowed%22%3Afalse%2C%22MinergieCertified%22%3Afalse%2C%22WheelchairAccessible%22%3Afalse%2C%22LowerLeftLatitude%22%3Anull%2C%22LowerLeftLongitude%22%3Anull%2C%22UpperRightLatitude%22%3Anull%2C%22UpperRightLongitude%22%3Anull%7D&sort=11',
#  'https://www.comparis.ch/immobilien/marktplatz/bern/weissenbuehl/wohnung/mieten',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23014336',
#  'https://www.comparis.ch/immobilien/marktplatz/bern/wohnung/mieten?page=2#top',
#  'https://www.comparis.ch/magazin',
#  'https://www.instagram.com/comparis_ch/',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23014339',
#  'https://fr.comparis.ch/immobilien/marktplatz/bern/wohnung/mieten?page=2']

# %%
links = list(set([x if len(str(re.findall('https://www.comparis.ch/immobilien/marktplatz/details/show/', str(x))))>=3 else 0 for x in flat_links]))[1:]

links
# Out:
# ['https://www.comparis.ch/immobilien/marktplatz/details/show/23014335',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23016559',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23016600',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23014346',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23014336',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23014342',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23016606',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23018295',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23014339',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23014344']

# %% [markdown]
# ## 1.2. get number of result pages

# %%
#amount of links
nr = list(set([x[-3:] if len(str(re.findall('page', str(x))))>=3 else 0 for x in flat_links]))[0:]


nrlis = ["".join(re.findall('[0-9]', str(x))) for x in nr]
resultpages=int(max(nrlis))
resultpages
# Out:
# 78

# %% [markdown]
# ## 1.3 loop for all pages

# %%
urlOhnePage = url[:-1]
for i in range(1, (resultpages-1)):
    page_url = urlOhnePage + str(i)
    driver.get(page_url)
    driver.execute_script("document.body.style.zoom = '0.1'")
    time.sleep(2.34)
    flats_link = driver.find_elements_by_class_name("excbu0j3")
    flat_links = list(set([flats.get_attribute('href') for flats in flats_link]))
    lin= list(set([x if len(str(re.findall('https://www.comparis.ch/immobilien/marktplatz/details/show/', str(x))))>=3 else 0 for x in flat_links]))[1:]
    for x in lin: 
        links.append(x)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in getresponse(self)
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in begin(self)
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _read_status(self)
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#
# ~\AppData\Local\Continuum\anaconda3\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ConnectionResetError: [WinError 10054] Eine vorhandene Verbindung wurde vom Remotehost geschlossen
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# <ipython-input-334-14fad30a9b08> in <module>
#       2 for i in range(1, (resultpages-1)):
#       3     page_url = urlOhnePage + str(i)
# ----> 4     driver.get(page_url)
#       5     driver.execute_script("document.body.style.zoom = '0.1'")
#       6     time.sleep(2.34)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     322             response = conn.urlopen(method, url, **kw)
#     323         else:
# --> 324             response = conn.urlopen(method, u.request_uri, **kw)
#     325
#     326         redirect_location = redirect and response.get_redirect_location()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     636
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#     640
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     366             # Read retry?
#     367             if read is False or not self._is_method_retryable(method):
# --> 368                 raise six.reraise(type(error), error, _stacktrace)
#     369             elif read is not None:
#     370                 read -= 1
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     683             value = tp()
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#     687
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                     # Remove the TypeError from the exception chain in Python 3;
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     386             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in getresponse(self)
#    1334         try:
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#    1338                 self.close()
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~\AppData\Local\Continuum\anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, 'Eine vorhandene Verbindung wurde vom Remotehost geschlossen', None, 10054, None))

# %%
# Out:
# 'https://www.comparis.ch/immobilien/marktplatz/bern/wohnung/mieten?page=2'

# %%
len(links)
# Out:
# 110

# %%
linkBern = pd.DataFrame(links)
linkBern.to_csv('linksBern.csv')

# %%
city = 'Bern'
## url for Bern and only flats
url = "https://www.comparis.ch/immobilien/result/list?requestobject=%7B%22DealType%22%3A10%2C%22SiteId%22%3A-1%2C%22RootPropertyTypes%22%3A%5B1%5D%2C%22PropertyTypes%22%3A%5B%5D%2C%22RoomsFrom%22%3Anull%2C%22RoomsTo%22%3Anull%2C%22FloorSearchType%22%3A0%2C%22LivingSpaceFrom%22%3Anull%2C%22LivingSpaceTo%22%3Anull%2C%22PriceFrom%22%3Anull%2C%22PriceTo%22%3Anull%2C%22ComparisPointsMin%22%3A-1%2C%22AdAgeMax%22%3A-1%2C%22AdAgeInHoursMax%22%3Anull%2C%22Keyword%22%3A%22%22%2C%22WithImagesOnly%22%3Anull%2C%22WithPointsOnly%22%3Anull%2C%22Radius%22%3Anull%2C%22MinAvailableDate%22%3A%221753-01-01T00%3A00%3A00%22%2C%22MinChangeDate%22%3A%221753-01-01T00%3A00%3A00%22%2C%22LocationSearchString%22%3A%22Bern%22%2C%22Sort%22%3A11%2C%22HasBalcony%22%3Afalse%2C%22HasTerrace%22%3Afalse%2C%22HasFireplace%22%3Afalse%2C%22HasDishwasher%22%3Afalse%2C%22HasWashingMachine%22%3Afalse%2C%22HasLift%22%3Afalse%2C%22HasParking%22%3Afalse%2C%22PetsAllowed%22%3Afalse%2C%22MinergieCertified%22%3Afalse%2C%22WheelchairAccessible%22%3Afalse%2C%22LowerLeftLatitude%22%3Anull%2C%22LowerLeftLongitude%22%3Anull%2C%22UpperRightLatitude%22%3Anull%2C%22UpperRightLongitude%22%3Anull%7D&page=0"

# %% [markdown]
# ### 1.1 Get the Links from Page 1

# %%
## get the soups
html = requests.get(url).content
html

soup = BeautifulSoup(html, "lxml")  # Check documentation to specify 'features'
soup.prettify()
soup
# Out:
# <!DOCTYPE html>
# <html lang="de-CH"><head><script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"30d2eb686c","applicationID":"63661895","transactionName":"NAYHNkEFVhUCVUQICw1MJDFjS20PKlhEBAMRAhELXApwBw1SXAQW","queueTime":0,"applicationTime":441,"agent":"","atts":""}</script><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"VQ8DVlNQCBAGV1dUBgkOUw==",licenseKey:"30d2eb686c",applicationID:"63661895"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(25),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(26),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError",l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),c.xhrWrappable&&t(14),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){L++,C=g.hash,this[u]=y.now()}function o(){L--,g.hash!==C&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable){var x=t(10),b=t(11),E=t(8),O=t(6),R=t(13),P=t(7),T=t(14),N=t(9),M=t("ee"),S=M.get("tracer");t(16),y.features.spa=!0;var C,L=0;M.on(u,r),M.on(p,r),M.on(d,o),M.on(l,o),M.buffer([u,d,"xhr-done","xhr-resolved"]),O.buffer([u]),R.buffer(["setTimeout"+c,"clearTimeout"+s,u]),T.buffer([u,"new-xhr","send-xhr"+s]),P.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),S.buffer([u,"no-"+u]),N.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(T,"send-xhr"+s),a(M,"xhr-resolved"),a(M,"xhr-done"),a(P,m+s),a(P,m+"-done"),a(N,"new-jsonp"),a(N,"jsonp-end"),a(N,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,L>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),s=t(12),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",p="resource",l="-start",h="-end",m="fn"+l,v="fn"+h,w="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(8),"addEventListener"in window&&t(6);var x=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),o.on(v,function(t,e){var n=t[0];n instanceof x&&i("bst ...
#   overflow: visible;
# }
#
# .svg-inline--fa {
#   display: inline-block;
#   font-size: inherit;
#   height: 1em;
#   overflow: visible;
#   vertical-align: -0.125em;
# }
# .svg-inline--fa.fa-lg {
#   vertical-align: -0.225em;
# }
# .svg-inline--fa.fa-w-1 {
#   width: 0.0625em;
# }
# .svg-inline--fa.fa-w-2 {
#   width: 0.125em;
# }
# .svg-inline--fa.fa-w-3 {
#   width: 0.1875em;
# }
# .svg-inline--fa.fa-w-4 {
#   width: 0.25em;
# }
# .svg-inline--fa.fa-w-5 {
#   width: 0.3125em;
# }
# .svg-inline--fa.fa-w-6 {
#   width: 0.375em;
# }
# .svg-inline--fa.fa-w-7 {
#   width: 0.4375em;
# }
# .svg-inline--fa.fa-w-8 {
#   width: 0.5em;
# }
# .svg-inline--fa.fa-w-9 {
#   width: 0.5625em;
# }
# .svg-inline--fa.fa-w-10 {
#   width: 0.625em;
# }
# .svg-inline--fa.fa-w-11 {
#   width: 0.6875em;
# }
# .svg-inline--fa.fa-w-12 {
#   width: 0.75em;
# }
# .svg-inline--fa.fa-w-13 {
#   width: 0.8125em;
# }
# .svg-inline--fa.fa-w-14 {
#   width: 0.875em;
# }
# .svg-inline--fa.fa-w-15 {
#   width: 0.9375em;
# }
# .svg-inline--fa.fa-w-16 {
#   width: 1em;
# }
# .svg-inline--fa.fa-w-17 {
#   width: 1.0625em;
# }
# .svg-inline--fa.fa-w-18 {
#   width: 1.125em;
# }
# .svg-inline--fa.fa-w-19 {
#   width: 1.1875em;
# }
# .svg-inline--fa.fa-w-20 {
#   width: 1.25em;
# }
# .svg-inline--fa.fa-pull-left {
#   margin-right: 0.3em;
#   width: auto;
# }
# .svg-inline--fa.fa-pull-right {
#   margin-left: 0.3em;
#   width: auto;
# }
# .svg-inline--fa.fa-border {
#   height: 1.5em;
# }
# .svg-inline--fa.fa-li {
#   width: 2em;
# }
# .svg-inline--fa.fa-fw {
#   width: 1.25em;
# }
#
# .fa-layers svg.svg-inline--fa {
#   bottom: 0;
#   left: 0;
#   margin: auto;
#   position: absolute;
#   right: 0;
#   top: 0;
# }
#
# .fa-layers {
#   display: inline-block;
#   height: 1em;
#   position: relative;
#   text-align: center;
#   vertical-align: -0.125em;
#   width: 1em;
# }
# .fa-layers svg.svg-inline--fa {
#   -webkit-transform-origin: center center;
#           transform-origin: center center;
# }
#
# .fa-layers-counter, .fa-layers-text {
#   display: inline-block;
#   position: absolute;
#   text-align: center;
# }
#
# .fa-layers-text {
#   left: 50%;
#   top: 50%;
#   -webkit-transform: translate(-50%, -50%);
#           transform: translate(-50%, -50%);
#   -webkit-transform-origin: center center;
#           transform-origin: center center;
# }
#
# .fa-layers-counter {
#   background-color: #ff253a;
#   border-radius: 1em;
#   -webkit-box-sizing: border-box;
#           box-sizing: border-box;
#   color: #fff;
#   height: 1.5em;
#   line-height: 1;
#   max-width: 5em;
#   min-width: 1.5em;
#   overflow: hidden;
#   padding: 0.25em;
#   right: 0;
#   text-overflow: ellipsis;
#   top: 0;
#   -webkit-transform: scale(0.25);
#           transform: scale(0.25);
#   -webkit-transform-origin: top right;
#           transform-origin: top right;
# }
#
# .fa-layers-bottom-right {
#   bottom: 0;
#   right: 0;
#   top: auto;
#   -webkit-transform: scale(0.25);
#           transform: scale(0.25);
#   -webkit-transform-origin: bottom right;
#           transform-origin: bottom right;
# }
#
# .fa-layers-bottom-left {
#   bottom: 0;
#   left: 0;
#   right: auto;
#   top: auto;
#   -webkit-transform: scale(0.25);
#           transform: scale(0.25);
#   -webkit-transform-origin: bottom left;
#           transform-origin: bottom left;
# }
#
# .fa-layers-top-right {
#   right: 0;
#   top: 0;
#   -webkit-transform: scale(0.25);
#           transform: scale(0.25);
#   -webkit-transform-origin: top right;
#           transform-origin: top right;
# }
#
# .fa-layers-top-left {
#   left: 0;
#   right: auto;
#   top: 0;
#   -webkit-transform: scale(0.25);
#           transform: scale(0.25);
#   -webkit-transform-origin: top left;
#           transform-origin: top left;
# }
#
# .fa-lg {
#   font-size: 1.3333333333em;
#   line-height: 0.75em;
#   vertical-align: -0.0667em;
# }
#
# .fa-xs {
#   font-size: 0.75em;
# }
#
# .fa-sm {
#   font-size: 0.875em;
# }
#
# .fa-1x {
#   font-size: 1em;
# }
#
# .fa-2x {
#   font-size: 2em;
# }
#
# .fa-3x {
#   font-size: 3em;
# }
#
# .fa-4x {
#   font-size: 4em;
# }
#
# .fa-5x {
#   font-size: 5em;
# }
#
# .fa-6x {
#   font-size: 6em;
# }
#
# .fa-7x {
#   font-size: 7em;
# }
#
# .fa-8x {
#   font-size: 8em;
# }
#
# .fa-9x {
#   font-size: 9em;
# }
#
# .fa-10x {
#   font-size: 10em;
# }
#
# .fa-fw {
#   text-align: center;
#   width: 1.25em;
# }
#
# .fa-ul {
#   list-style-type: none;
#   margin-left: 2.5em;
#   padding-left: 0;
# }
# .fa-ul > li {
#   position: relative;
# }
#
# .fa-li {
#   left: -2em;
#   position: absolute;
#   text-align: center;
#   width: 2em;
#   line-height: inherit;
# }
#
# .fa-border {
#   border: solid 0.08em #eee;
#   border-radius: 0.1em;
#   padding: 0.2em 0.25em 0.15em;
# }
#
# .fa-pull-left {
#   float: left;
# }
#
# .fa-pull-right {
#   float: right;
# }
#
# .fa.fa-pull-left,
# .fas.fa-pull-left,
# .far.fa-pull-left,
# .fal.fa-pull-left,
# .fab.fa-pull-left {
#   margin-right: 0.3em;
# }
# .fa.fa-pull-right,
# .fas.fa-pull-right,
# .far.fa-pull-right,
# .fal.fa-pull-right,
# .fab.fa-pull-right {
#   margin-left: 0.3em;
# }
#
# .fa-spin {
#   -webkit-animation: fa-spin 2s infinite linear;
#           animation: fa-spin 2s infinite linear;
# }
#
# .fa-pulse {
#   -webkit-animation: fa-spin 1s infinite steps(8);
#           animation: fa-spin 1s infinite steps(8);
# }
#
# @-webkit-keyframes fa-spin {
#   0% {
#     -webkit-transform: rotate(0deg);
#             transform: rotate(0deg);
#   }
#   100% {
#     -webkit-transform: rotate(360deg);
#             transform: rotate(360deg);
#   }
# }
#
# @keyframes fa-spin {
#   0% {
#     -webkit-transform: rotate(0deg);
#             transform: rotate(0deg);
#   }
#   100% {
#     -webkit-transform: rotate(360deg);
#             transform: rotate(360deg);
#   }
# }
# .fa-rotate-90 {
#   -ms-filter: "progid:DXImageTransform.Microsoft.BasicImage(rotation=1)";
#   -webkit-transform: rotate(90deg);
#           transform: rotate(90deg);
# }
#
# .fa-rotate-180 {
#   -ms-filter: "progid:DXImageTransform.Microsoft.BasicImage(rotation=2)";
#   -webkit-transform: rotate(180deg);
#           transform: rotate(180deg);
# }
#
# .fa-rotate-270 {
#   -ms-filter: "progid:DXImageTransform.Microsoft.BasicImage(rotation=3)";
#   -webkit-transform: rotate(270deg);
#           transform: rotate(270deg);
# }
#
# .fa-flip-horizontal {
#   -ms-filter: "progid:DXImageTransform.Microsoft.BasicImage(rotation=0, mirror=1)";
#   -webkit-transform: scale(-1, 1);
#           transform: scale(-1, 1);
# }
#
# .fa-flip-vertical {
#   -ms-filter: "progid:DXImageTransform.Microsoft.BasicImage(rotation=2, mirror=1)";
#   -webkit-transform: scale(1, -1);
#           transform: scale(1, -1);
# }
#
# .fa-flip-both, .fa-flip-horizontal.fa-flip-vertical {
#   -ms-filter: "progid:DXImageTransform.Microsoft.BasicImage(rotation=2, mirror=1)";
#   -webkit-transform: scale(-1, -1);
#           transform: scale(-1, -1);
# }
#
# :root .fa-rotate-90,
# :root .fa-rotate-180,
# :root .fa-rotate-270,
# :root .fa-flip-horizontal,
# :root .fa-flip-vertical,
# :root .fa-flip-both {
#   -webkit-filter: none;
#           filter: none;
# }
#
# .fa-stack {
#   display: inline-block;
#   height: 2em;
#   position: relative;
#   width: 2.5em;
# }
#
# .fa-stack-1x,
# .fa-stack-2x {
#   bottom: 0;
#   left: 0;
#   margin: auto;
#   position: absolute;
#   right: 0;
#   top: 0;
# }
#
# .svg-inline--fa.fa-stack-1x {
#   height: 1em;
#   width: 1.25em;
# }
# .svg-inline--fa.fa-stack-2x {
#   height: 2em;
#   width: 2.5em;
# }
#
# .fa-inverse {
#   color: #fff;
# }
#
# .sr-only {
#   border: 0;
#   clip: rect(0, 0, 0, 0);
#   height: 1px;
#   margin: -1px;
#   overflow: hidden;
#   padding: 0;
#   position: absolute;
#   width: 1px;
# }
#
# .sr-only-focusable:active, .sr-only-focusable:focus {
#   clip: auto;
#   height: auto;
#   margin: 0;
#   overflow: visible;
#   position: static;
#   width: auto;
# }
#
# .svg-inline--fa .fa-primary {
#   fill: var(--fa-primary-color, currentColor);
#   opacity: 1;
#   opacity: var(--fa-primary-opacity, 1);
# }
#
# .svg-inline--fa .fa-secondary {
#   fill: var(--fa-secondary-color, currentColor);
#   opacity: 0.4;
#   opacity: var(--fa-secondary-opacity, 0.4);
# }
#
# .svg-inline--fa.fa-swap-opacity .fa-primary {
#   opacity: 0.4;
#   opacity: var(--fa-secondary-opacity, 0.4);
# }
#
# .svg-inline--fa.fa-swap-opacity .fa-secondary {
#   opacity: 1;
#   opacity: var(--fa-primary-opacity, 1);
# }
#
# .svg-inline--fa mask .fa-primary,
# .svg-inline--fa mask .fa-secondary {
#   fill: black;
# }
#
# .fad.fa-inverse {
#   color: #fff;
# }</style><script type="text/javascript">window.dataLayer = window.dataLayer || [];
#           window.dataLayer.push({"event":"siteWideVariables","pvEnvironment":"web","pvos":"unknown","pvDeviceType":"unknown","umUserTrackingCookieGID":"57a575a4-e14c-4bc3-a5fd-e48e11e24ec4","umSessionID":"248d6da2-a342-4692-800f-410ce00d377d","flKaufenMiete":"undefined","partnerNames":"undefined","umUserRecognitionState":"anonymous","splittestingConfig":"[]","websiteLanguage":"de","customerID":"00000000-0000-0000-0000-000000000000","environmentType":"Production"})
#           window.dataLayer.push({
# "event": "siteWideVariables",
# "pvReactOriginalDocumentLocation": window.location.href,
# "pvReactPageURL": window.location.pathname + window.location.search
# })</script><script type="text/javascript">(function(w, d, s, l, i) {
#             {
#                 w[l] = w[l] || [];
#                 w[l].push({
#                         'gtm.start': new Date().getTime(),
#                         event: 'gtm.js'
#                     }
#                 );
#                 var f = d.getElementsByTagName(s)[0],
#                     j = d.createElement(s),
#                     dl = l != 'dataLayer' ? '&l=' + l : '';
#                 j.async = true;
#                 j.src =
#                     'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#                 f.parentNode.insertBefore(j, f);
#             }
#           })(window, document, 'script', 'dataLayer', 'GTM-MQRSPX7');</script><link href="https://ad.doubleclick.net" rel="preconnect"/><link href="https://adservice.google.com" rel="preconnect"/><link href="https://cdn.ampproject.org" rel="preconnect"/><link href="https://tpc.googlesyndication.com" rel="preconnect"/><script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script><script>window.googletag = window.googletag || {cmd: []};</script><script type="text/javascript">(function(i, s, o, g, r, a, m) {
#               i['GoogleAnalyticsObject'] = r;
#               i[r] = i[r] || function() {
#                   (i[r].q = i[r].q || []).push(arguments)
#               }, i[r].l = 1 * new Date();
#               a = s.createElement(o),
#                   m = s.getElementsByTagName(o)[0];
#               a.defer = 1;
#               a.src = g;
#               m.parentNode.insertBefore(a, m)
#           })(window, document, "script", "//www.google-analytics.com/analytics.js", "ga");
#
#           ga("create", "UA-55460714-2", "auto", {
#               "siteSpeedSampleRate": 1
#           });
#           ga("require", "linkid", "linkid.js");</script><script src="https://cdn.optimizely.com/js/12109504304.js" type="text/javascript"></script><style data-emotion-css="jfe55c">{font-family:'Roboto';font-style:normal;font-weight:300;font-display:swap;src:local('Roboto Light'),local('Roboto-Light'), url(/asset/default/file/css/responsive/webfonts/roboto/roboto-v20-latin-300.woff2) format('woff2'), url(/asset/default/file/css/responsive/webfonts/roboto/roboto-v20-latin-300.woff) format('woff');}html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,main,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section{display:block;}*[hidden]{display:none;}body{line-height:1;}ol,ul{list-style:none;}blockquote,q{quotes:none;}blockquote:before,blockquote:after,q:before,q:after{content:"";content:none;}table{border-collapse:collapse;border-spacing:0;}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;font-display:swap;src:local('Roboto'),local('Roboto-Regular'), url(/asset/default/file/css/responsive/webfonts/roboto/roboto-v20-latin-regular.woff2) format('woff2'), url(/asset/default/file/css/responsive/webfonts/roboto/roboto-v20-latin-regular.woff) format('woff');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;font-display:swap;src:local('Roboto Medium'),local('Roboto-Medium'), url(/asset/default/file/css/responsive/webfonts/roboto/roboto-v20-latin-500.woff2) format('woff2'), url(/asset/default/file/css/responsive/webfonts/roboto/roboto-v20-latin-500.woff) format('woff');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;font-display:swap;src:local('Roboto Bold'),local('Roboto-Bold'), url(/asset/default/file/css/responsive/webfonts/roboto/roboto-v20-latin-700.woff2) format('woff2'), url(/asset/default/file/css/responsive/webfonts/roboto/roboto-v20-latin-700.woff) format('woff');}html{font-size:0.625em;}body{font-size:1.6rem;font-size-adjust:none;-moz-osx-font-smoothing:grayscale;-webkit-text-size-adjust:none;-webkit-font-smoothing:antialiased;}html,body{font-family:Roboto,sans-serif;background-color:#ffffff;}strong{font-weight:700;}button{display:block;background:none;border:none;outline:none;padding:0;font:inherit;font-family:Roboto,sans-serif;font-weight:500;}button:hover:not([disabled]){cursor:pointer;}button:hover:disabled{cursor:not-allowed;}a{-webkit-text-decoration:none;text-decoration:none;font-family:Roboto,sans-serif;font-weight:500;}select{border-radius:0;}</style><meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/><meta charset="utf-8"/><title>Wohnung mieten in Bern - Vergleiche 780 Inserate mit comparis.ch</title><meta content="Wohnung mieten in Bern ganz einfach mit comparis.ch. Alle Angebote zur Miete verschiedener Immobilienportale auf einen Blick mit Angaben zum Sparpotenzial." name="description"/><meta content="index,follow" name="robots"/><link href="https://www.comparis.ch/immobilien/marktplatz/bern/wohnung/mieten?page=1" rel="next"/><link href="https://www.comparis.ch/immobilien/marktplatz/bern/wohnung/mieten" rel="canonical"/><link href="https://www.comparis.ch/immobilien/marktplatz/bern/wohnung/mieten" hreflang="de-ch" rel="alternate"/><link href="https://fr.comparis.ch/immobilien/marktplatz/bern/wohnung/mieten" hreflang="fr-ch" rel="alternate"/><link href="https://it.comparis.ch/immobilien/marktplatz/bern/wohnung/mieten" hreflang="it-ch" rel="alternate"/><link href="https://en.comparis.ch/immobilien/marktplatz/bern/wohnung/mieten" hreflang="en" rel="alternate"/><link href="/immob ...

# %%
print(soup.title)
# Out:
# <title>mieten in Bern - Vergleiche 780 Inserate mit comparis.ch</title>

# %%
##get the links
#css-5snccb excbu0j0
link = []

for div in soup.find_all('div', attrs = {'class':'css-5snccb excbu0j0'}):
    for a in div.find_all('a'):
           link.append(a.get('href'))

link
# Out:
# ['/immobilien/marktplatz/details/show/23024420',
#  '/immobilien/marktplatz/details/show/23024399',
#  '/immobilien/marktplatz/details/show/23024131',
#  '/immobilien/marktplatz/details/show/23023616']

# %% [markdown]
# ##### backup

# %%
# titles of flats --not needed --> delete
h3=soup.find_all('h3') 

beschreibung = [element.text for element in h3]
beschreibung
# Out:
# ['Filter',
#  '1.5 Zimmer, 30 m²',
#  '1 Zimmer, 45 m²',
#  '2.5 Zimmer, 59 m², 2. Etage',
#  '2.5 Zimmer, 802 m²']

# %%
## price --> just as backup
price = soup.find_all('span', attrs = {'class':'css-19smxur excbu0j2'})
price
prices = [element.text for element in table]
prices
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-74c0d5d38310> in <module>
#       2 price = soup.find_all('span', attrs = {'class':'css-19smxur excbu0j2'})
#       3 price
# ----> 4 prices = [element.text for element in table]
#       5 prices
#
# NameError: name 'table' is not defined

# %% [markdown]
# # 2. Detailed Infos for each flat

# %% [markdown]
# ## 2.1 List of links?

# %%
linkBern = ["https://www.comparis.ch"+l for l in link]
linkBern
# Out:
# ['https://www.comparis.ch/immobilien/marktplatz/details/show/23024420',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23024399',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23024131',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23023616']

# %% [markdown]
# ## 2.2 Infos for one flat

# %% [markdown]
# #### 2.2.0 get soup

# %%
url2 = linkBern[0]

html2 = requests.get(url2).content
html2

soup2 = BeautifulSoup(html2, "lxml")  # Check documentation to specify 'features'
soup2
# Out:
# <!DOCTYPE html>
# <html lang="De">
# <head>
# <title>1½ Zimmer Wohnung in 3008 Bern  – Immobilienmarkt von comparis.ch</title>
# <meta content="follow,noindex" name="robots"/>
# <meta content="Wohnung, 1½ Zimmer Wohnung, Miete, 3008 Bern " name="keywords"/>
# <meta content="1½ Zimmer Wohnung in 3008 Bern , Mietpreis / Monat 890 CHF  " name="description"/>
# <meta content="comparis.ch AG" name="copyright"/>
# <meta content="de" http-equiv="Content-Language"/>
# <meta content="de" name="language"/>
# <meta content="private" http-equiv="Cache-Control"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/><script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"30d2eb686c","applicationID":"63661895","transactionName":"NAYHNkEFVhUCVUQICw1MJDFjS20PKlhEBAMRAhELXApwBw1SXAQW","queueTime":0,"applicationTime":543,"agent":"","atts":""}</script><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"VQ8DVlNQCBAGV1dUBgkOUw==",licenseKey:"30d2eb686c",applicationID:"63661895"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(25),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(26),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError",l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),c.xhrWrappable&&t(14),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){L++,C=g.hash,this[u]=y.now()}function o(){L--,g.hash!==C&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable){var x=t(10),b=t(11),E=t(8),O=t(6),R=t(13),P=t(7),T=t(14),N=t(9),M=t("ee"),S=M.get("tracer");t(16),y.features.spa=!0;var C,L=0;M.on(u,r),M.on(p,r),M.on(d,o),M.on(l,o),M.buffer([u,d,"xhr-done","xhr-resolved"]),O.buffer([u]),R.buffer(["setTimeout"+c,"clearTimeout"+s,u]),T.buffer([u,"new-xhr","send-xhr"+s]),P.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),S.buffer([u,"no-"+u]),N.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(T,"send-xhr"+s),a(M,"xhr-resolved"),a(M,"xhr-done"),a(P,m+s),a(P,m+"-done"),a(N,"new-jsonp"),a(N,"jsonp-end"),a(N,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,L>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),s=t(12),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",p="resource",l="-start",h="-end",m="fn"+l,v="fn"+h,w="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(8),"addEventListener"in window&&t(6);var x=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),o.on(v,function(t,e){var  ...
# <meta content="utf-8" property="charset"/>
# <meta content="VoCfOaTipeb2lm/zZFAgL3o9OwS2WyFOo3YbjnUKMnU=" name="verify-v1"/>
# <meta content="f8428b8355306eb5" name="y_key"/>
# <meta content="7F06A1DE4D8C6ED8AB24B3A1EA7356B7" name="msvalidate.01"/>
# <meta content="Ii9L6UhICzdiSmdfNdVK7YJcm1zs3N9laDUpNAXGUPs" name="google-site-verification"/>
# <meta content='{"exception": {"Enable": true}, "remote": {"LogLevel": 4, "LoggerPath": "/comparis/api/log"}, "console": {"LogLevel": 5}, "ui": {"LogLevel": 5}}' name="loggerSetting"/>
# <meta content="https://www.comparis.ch/immobilien/marktplatz/details/show/23024420" name="lytics:canonical"/>
# <meta content="desktop" name="t.env:pv-req"/>
# <meta content="web" name="t.env:pv-env"/>
# <meta content="desktop" name="t.env:pv-view"/>
# <meta content="robot" name="t.env:pv-os"/>
# <meta content="desktop" name="t.env:pv-dev"/>
# <meta content="unknown" name="t.env:pv-window"/>
# <meta content="" name="t.env:qrystr"/>
# <meta content="/immobilien/marktplatz/detail.aspx" name="t.env:page"/>
# <meta content="/immobilien/marktplatz/details/show/23024420" name="t.env:raw-url"/>
# <meta content="comparis.ch" name="t.env:pagetitle"/>
# <meta content="e05ecd2e-5447-47fb-b233-b2d30247be4f" name="t.env:um_usertrackingcookiegid"/>
# <meta content="04634b3b-a395-45d2-b435-3fd14ba263c8" name="t.env:um_sessionid"/>
# <meta content="anonymous" name="t.env:recognitionState"/>
# <meta content="[]" name="t.env:splittestingConfig"/>
# <meta content="de" name="t.env:language"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta class="swiftype" content="1½ Zimmer Wohnung in 3008 Bern  – Immobilienmarkt von comparis.ch" data-type="string" name="title"/>
# <meta class="swiftype" content="1½ Zimmer Wohnung in 3008 Bern , Mietpreis / Monat 890 CHF  " data-type="text" name="body"/>
# <meta class="swiftype" content="de" data-type="string" name="domain-filter"/>
# <link href="https://www.comparis.ch/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="https://www.comparis.ch/apple-touch-icon.png" rel="apple-touch-icon" type="image/png"/>
# <link href="https://www.comparis.ch/asset/responsive/group/framework.scss?h=3539296593" rel="stylesheet" type="text/css"/>
# <script src="https://www.comparis.ch/asset/responsive/group/framework.js?h=3942424042" type="text/javascript">
# </script>
# <script src="https://www.comparis.ch/asset/responsive/group/mvcValidation.js?h=3942535840" type="text/javascript">
# </script>
# <script src="https://aka-cdn.adtech.de/dt/common/DAC.js" type="text/javascript">
# </script>
# <script async="async" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>window.googletag = window.googletag || { cmd: [] };</script>
# <!-- Ad Unit Path: /261058272/comparis.de/immobilien/immobilienmarkt -->
# <script>googletag.cmd.push(function() {
# googletag.pubads().enableSingleRequest();
# googletag.pubads().enableLazyLoad({fetchMarginPercent:-1,renderMarginPercent:20,mobileScaling:1.0});
# googletag.pubads().setForceSafeFrame(true);
# googletag.pubads().setSafeFrameConfig({sandbox:true});
# googletag.pubads().collapseEmptyDivs();
# googletag.pubads().setTargeting('immoZipCode',['3008']).setTargeting('immoCanton',['BE']).setTargeting('immoBuyRent',['rent']).setTargeting('immoRent',['800-899']).setTargeting('immoType',['apartment']).setTargeting('immoRooms',['1.5']).setTargeting('immoArea',['30-39']).setTargeting('cantonCurrent',['BE']).setTargeting('cantonSearch',['BE']).setTargeting('zipCodeCurrent',['3008']).setTargeting('zipCodeSearch',['3008']).setTargeting('propertyBuyRent',['Rent']).setTargeting('propertyType',['Flat']).setTargeting('environment',['Production']).setTargeting('loginState',['LoggedOut']).setTargeting('pageCategory',['Detail']).setTargeting('url',['/immobilien/marktplatz/details/show/23024420']);
# var sbp=[
# {slot:googletag.defineSlot('/261058272/comparis.de/immobilien/immobilienmarkt',[[0,0]],'ad-slot-half-page-skyscraper-right').addService(googletag.pubads()).setTargeting('adSlotPosition',['right']).defineSizeMapping(googletag.sizeMapping().addSize([1151,0],[[300,600]]).addSize([1080,0],[[160,600]]).addSize([0,0],[]).build()),breakpoints:[[1151,0],[1080,0],[0,0]]},
# {slot:googletag.defineSlot('/261058272/comparis.de/immobilien/immobilienmarkt',[],'ad-slot-leaderboard-center').addService(googletag.pubads()).setTargeting('adSlotPosition',['center']).defineSizeMapping(googletag.sizeMapping().addSize([1355,0],[]).addSize([740,0],[[728,90]]).addSize([0,0],[]).build()),breakpoints:[[1355,0],[740,0],[0,0]]},
# {slot:googletag.defineSlot('/261058272/comparis.de/immobilien/immobilienmarkt',[],'ad-slot-mobile-sizes-mobile-center').addService(googletag.pubads()).setTargeting('adSlotPosition',['mobileCenter']).defineSizeMapping(googletag.sizeMapping().addSize([740,0],[]).addSize([0,0],[[300,250],[320,160],[320,100]]).build()),breakpoints:[[740,0],[0,0]]},
# {slot:googletag.defineSlot('/261058272/comparis.de/immobilien/immobilienmarkt',[],'ad-slot-wideboard-maxiboard-billboard-bottom').addService(googletag.pubads()).setTargeting('adSlotPosition',['bottom']).defineSizeMapping(googletag.sizeMapping().addSize([1355,0],[[994,250],[994,118],[970,250]]).addSize([1331,0],[[970,250]]).addSize([0,0],[]).build()),breakpoints:[[1355,0],[1331,0],[0,0]]}];
# googletag.enableServices();
# if (comparis) comparis.require('framework.responsive.ui.adSlotResize').addSlotBreakpointPairs(sbp);
# });</script>
# <!-- begin: DataLayerTracker tag -->
# <script type="text/javascript">window.dataLayer = window.dataLayer || [];window.dataLayer.push({'event': 'siteWideVariables','pvEnvironment': 'web','pvos': 'robot','pvDeviceType': 'desktop','umUserTrackingCookieGID': 'e05ecd2e-5447-47fb-b233-b2d30247be4f','umSessionID': '04634b3b-a395-45d2-b435-3fd14ba263c8','flKaufenMiete': 'undefined','partnerNames': 'undefined','umUserRecognitionState': 'anonymous','splittestingConfig': '[]','partialViewsLoaded': 'undefined','pvWindowSize': 'unknown','websiteLanguage': 'de','customerID': null,'environmentType': 'Production'});
# function logEventFirebaseTracking(name, params) {
#                   'use strict';
#                   // v.1.1.0
#
#                  //This code is closely bound to the Marketplaces native iOS and Android Apps and therefore should not be changed.
#                  try{
#                   if (!name) {
#                     return;
#                   }
#
#                   if (window.AnalyticsWebInterface) {
#                     // Call Android interface
#                     window.AnalyticsWebInterface.logEvent(name, JSON.stringify(params));
#                   } else if (window.webkit
#                       && window.webkit.messageHandlers
#                       && window.webkit.messageHandlers.firebase) {
#                     // Call iOS interface
#                     var message = {
#                       command: 'logEvent',
#                       name: name,
#                       parameters: params
#                     };
#                     window.webkit.messageHandlers.firebase.postMessage(message);
#                   }
#                  }catch(err){}
#                 } var firebaseSiteWideVariablesParams = {'pvEnvironment': 'web','pvos': 'robot','pvDeviceType': 'desktop','umUserTrackingCookieGID': 'e05ecd2e-5447-47fb-b233-b2d30247be4f','umSessionID': '04634b3b-a395-45d2-b435-3fd14ba263c8','flKaufenMiete': 'undefined','partnerNames': 'undefined','umUserRecognitionState': 'anonymous','splittestingConfig': '[]','partialViewsLoaded': 'undefined','pvWindowSize': 'not set','websiteLanguage': 'de','customerID': null,'environmentType': 'Production'};  logEventFirebaseTracking('siteWideVariables', firebaseSiteWideVariablesParams);
# </script>
# <!-- end: DataLayerTracker tag -->
# <!-- begin: Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 								new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 								j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 								'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 								})(window,document,'script','dataLayer','GTM-MQRSPX7');
#
# 								// Init mapping table for gtm dimensions
# 								(function(){
# 								var mapper = comparis.require('framework.tracking.processor.gtm.parameterMapper');
# 								mapper.addDimension('wt-tr-event','undefined');
# mapper.addDimension('wt-tr-eventtype','undefined');
# mapper.addDimension('wt-application','common.application');
# mapper.addDimension('wt-pagename','common.pageName');
# mapper.addDimension('wt-fa-label','funnelaction.label');
# mapper.addDimension('wt-process','common.process');
# mapper.addDimension('wt-ss-label','section.sectionName');
# mapper.addDimension('wt-fe-label','formerrors.label');
# mapper.addDimension('wt-fe-language','formerrors.language');
# mapper.addDimension('wt-fe-infobasekey','formerrors.InfobaseKey');
# mapper.addDimension('wt-fe-messagetext','formerrors.messageText');
# mapper.addDimension('wt-fc-label','filterchange.label');
# mapper.addDimension('wt-rentorbuy','funnelaction.rentorbuy');
# mapper.addDimension('wt-propertytype','funnelaction.propertyType');
# mapper.addDimension('wt-propertysize','funnelaction.PropertySize');
# mapper.addDimension('wt-propertyprice','funnelaction.PropertyPrice');
# mapper.addDimension('wt-carcategory','funnelaction.carcategory');
# mapper.addDimension('wt-bodytype','funnelaction.bodytype');
# mapper.addDimension('wt-brand','funnelaction.brand');
# mapper.addDimension('wt-popularmodel','funnelaction.popularmodel');
# mapper.addDimension('wt-partnername','funnelaction.partnerNames');
# mapper.addDimension('wt-model','funnelaction.model');
# mapper.addDimension('wt-tyrewidth','funnelaction.tyreWidth');
# mapper.addDimension('wt-tyreprofile','funnelaction.tyreProfile');
# mapper.addDimension('wt-tyrerim','funnelaction.tyreRim');
# mapper.addDimension('wt-tyretype','funnelaction.tyreType');
# mapper.addDimension('wt-status','common.status');
# mapper.addDimension('wt-cross-label','navigation.label');
# mapper.addDimension('wt-ec-application','products.name');
# mapper.addDimension('wt-ec-process','products.dimension36');
# mapper.addDimension('wt-ec-viewtype','products.dimension37');
# mapper.addDimension('wt-ec-list','actionField.list');
# mapper.addDimension('wt-ec-provider','products.dimension33');
# mapper.addDimension('wt-ec-productname','products.dimension34');
# mapper.addDimension('wt-ec-producttype','products.dimension35');
# mapper.addDimension('wt-ec-productbrand','products.brand');
# mapper.addDimension('wt-ec-productposition','products.position');
# mapper.addDimension('wt-ec-productid','products.id');
# mapper.addDimension('wt-ec-productrevenue','products.price');
# mapper.addDimension('wt-ec-currencycode','currencyCode');
# mapper.addDimension('wt-ec-revenue','actionField.revenue');
# mapper.addDimension('wt-ec-productquantity','products.quantity');
# mapper.addDimension('wt-ec-productstate','products.dimension42');
# mapper.addDimension('wt-ec-relatedproduct','products.dimension43');
# mapper.addDimension('wt-ec-actionfieldid','actionField.id');
# mapper.addDimension('wt-ec-score','user.score');
# mapper.addDimension('wt-ec-exvol','user.exvol');
# mapper.addDimension('wt-ec-bisvol','user.bisvol');
# mapper.addDimension('wt-ec-productsubtype','products.dimension79');
# mapper.addDimension('wt-ec-ip-name','promotions.name');
# mapper.addDimension('wt-ec-ip-creative','promotions.creative');
# mapper.addDimension('wt-ec-ip-position','promotions.position');
# mapper.addDimension('wt-ex-gender','extTracking.gender');
# mapper.addDimension('wt-ex-zipcode','extTracking.zipcode');
# mapper.addDimension('wt-ex-birthyear','extTracking.birthyear');
# mapper.addDimension('wt-ex-currentinsurer','extTracking.currentInsurer');
# mapper.addDimension('wt-ex-savingpotential','extTracking.savingPotential');
# mapper.addDimension('wt-ex-franchise','extTracking.franchise');
# mapper.addDimension('wt-ex-personcount','extTracking.personCount');
# mapper.addDimension('wt-ex-insurancemodel','extTracking.insuranceModel');
# mapper.addDimension('wt-ex-productprice','extTracking.productPrice');
# mapper.addDimension('wt-ex-processstep','extTracking.processStep');
# mapper.addDimension('wt-ev-label','elementView.label');
#
# 								}());
#
#
# </script>
# <!-- end: Google Tag Manager -->
# <!-- begin: Optimizely -->
# <script src="//cdn.optimizely.com/js/12109504304.js" type="text/javascript">
# </script>
# <!-- end: Optimizely -->
# <!-- NavState:immobilien, PageCategoryPath:immobilien.detail -->
# <meta content="1½ Zimmer Wohnung in 3008 Bern  – Immobilienmarkt von comparis.ch" property="og:title"/><meta content="article" property="og:type"/><meta content="https://www.comparis.ch/immobilien/marktplatz/details/show/23024420" property="og:url"/><meta content="https://www.comparis.ch/immobilien/api/image/getdirect?guid=ca02497b-f339-44a9-a937-1977cf810e05&amp;w=1200&amp;h=630&amp;rm=3" property="og:image"/><meta content="1½ Zimmer Wohnung in 3008 Bern , Mietpreis / Monat 890 CHF  " property="og:description"/><meta content="comparis.ch" property="og:site_name"/><meta content="354639737960358" property="fb:app_id"/><meta content="https://www.facebook.com/comparis.ch" property="article:publisher"/><meta content="unsafe-url" name="referrer"/><meta content="app-id=328172261, affiliate-data=, app-argument=https://www.comparis.ch/immobilien/marktplatz/details/show/23024420" name="apple-itunes-app"/><meta content="AxaAd" name="t.env:partialViewsLoaded"/><meta content="mieten" name="t.env:kaufen-miete"/><script src="/immobilien/asset/default/group/finder-hf-soa-general.js" type="text/javascript">
# </script><link href="/immobilien/asset/default/group/finder-hf-soa-general.css?h=2661087894" rel="stylesheet" type="text/css"/><link href="/immobilien/asset/responsive/group/finder-hf-detail-newsletter-default-implementation-v1.css?h=2659249857" rel="stylesheet" type="text/css"/><script src="/immobilien/asset/responsive/group/finder-hf-detail-newsletter-default-implementation-v3.js?h=2660311411" type="text/javascript">
# </script><link href="/immobilien/asset/responsive/file/resources/styles/hf-detail-contactform-promotion.css?h=2661087894" rel="stylesheet" type="text/css"/><script src="https://www.comp-osm.ch/leaflet.js" type="text/javascript">
# </script><script src="https://www.comp-osm.ch/Control.FullScreen.js" type="text/javascript">
# </script><script src="https://www.comp-osm.ch/leaflet-gesture-handling.min.js" type="text/javascript">
# </script><script src="https://www.comp-osm.ch/easy-button.js" type="text/javascript">
# </script><script src="/immobilien/asset/responsive/file/resources/scripts/contactformcontainer.module.js?h=2666692718" type="text/javascript">
# </script><script src="/immobilien/asset/responsive/file/resources/scripts/contactButtonVisibility.module.js?h=2666692718" type="text/javascript">
# </script><script src="/immobilien/asset/responsive/group/finder-hf-soa-redirectclick.js?h=2629424572" type="text/javascript">
# </script><script src="/finderasset/default/file/assets/scripts/common/extlib/Jssor.js?h=2975308449" type="text/javascript">
# </script><script src="/finderasset/default/group/finder.js?h=2973668033" type="text/javascript">
# </script></head>
# <body class="has-ad-sky lang-de" data-ct-area="layoutapigateway" data-pvt="false" id="top">
# <script type="text/javascript">
# comparis.initializeModulesByEvent('modules-loaded');
# window.suggestmeyes_loaded = true;
# </script>
# <!-- begin: Google Tag Manager (no script) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MQRSPX7" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- end: Google Tag Manager (no script) -->
# <header class="head no-print" data-head="">
# <div class="head-inner-wrap">
# <div class="head-top">
# <div class="head-top-inner" data-head-top-inner="">
# <div class="row">
# <div class="xsmall-8 medium-3 column">
# <a class="logo" href="/">
# <img alt="comparis.ch Logo" src="https://www.comparis.ch/img/logo/logo-comparis-homepage.png"/>
# </a>
# </div>
# <div class="xsmall-4 medium-9 column head-top-right" data-head-top-right="">
# <div class="hide-for-medium">
# <a class="search-toggle" data-search-toggle="" href="#search">
# <span class="icn-circled">
# <i class="fa fa-search">
# </i>
# <span class="show-for-sr">Suche</span>
# </span>
# </a>
# <a class="menu-toggle menu-button-hidden" daca-ct-id="MenuButton" data-ct="true" data-ct-area="navigation" data-ct-subtype="Main" data-ct-type="Menu" data-menu-toggle="" href="#nav-main">
# <ul class="header-menu-list">
# <li><span class="bars"></span></li>
# <li><span class="header-menu-text">Menü</span></li>
# </ul>
# </a>
# </div>
# <ul class="nav-meta navigation-mobile" data-nav-meta1="">
# <li><a class="newsletter" data-wt-cross-label="Header - Newsletter" data-wt-tr-event="navigation" href="https://www.comparis.ch/comparis/newsletter/subscribe"><span class="icn-circled"><img class="header-icons show-for-medium" src="https://www.comparis.ch/img/headericons/envelope-solid.svg"/><img class="header-icons show-for-xsmall-up hide-for-medium" src="https://www.comparis.ch/img/headericons/envelope-dark-solid.svg"/></span>Newsletter</a></li>
# <li><a class="magazine-element" data-wt-cross-label="Header - Magazine" data-wt-tr-event="navigation" href="https://www.comparis.ch/magazin"><span class="icn-circled"><img class="header-icons show-for-medium" src="https://www.comparis.ch/img/headericons/book-reader-solid.svg"/><img class="header-icons show-for-xsmall-up hide-for-medium" src="https://www.comparis.ch/img/headericons/book-reader-dark-solid.svg"/></span>Magazin</a></li>
# <li class="show-for-medium">
# <a class="lang-toggle" data-lang-toggle="" id="lang-dropdown">
#
#                                                 DE
#                                                 <span>
# <i class="fa fa-angle-down">
# </i>
# </span>
# </a>
# </li>
# <li class="show-for-medium">
# <a data-pc-href="https://www.comparis.ch/Authentication/Login?successUrl=%2fmycomparis%2fbereich%3fappCode%3dHF%26source%3d%252fimmobilien%252fmarktplatz%252fdetails%252fshow%252f23024420" data-pc-hrefcallback="framework.authentication.processHref" data-pc-windowtype="overlaydiv" data-rel="process" data-wt-cross-label="Header - Login" data-wt-tr-event="navigation" href="https://www.comparis.ch/mycomparis/bereich?appCode=HF&amp;source=%2fimmobilien%2fmarktplatz%2fdetails%2fshow%2f23024420" rel="nofollow"><span class="icn-circled">
# <i class="fa fa-user">
# </i>
# </span>Login</a>
# </li>
# <li class="hide-for-medium list-lang-medium header-tracking">
# <nav>
# <ul class="nav-lang">
# <li class="active">
# <a data-wt-cross-label="Footer - Language - De" data-wt-tr-event="navigation" href="https://www.comparis.ch/immobilien/marktplatz/details/show/23024420" hreflang="De" lang="De" rel="alternate">De</a>
# </li>
# <li>
# <a data-wt-cross-label="Footer - Language - Fr" data-wt-tr-event="navigation" href="https://fr.comparis.ch/immobilien/marktplatz/details/show/23024420" hreflang="Fr" lang="Fr" rel="alternate">Fr</a>
# </li>
# <li>
# <a data-wt-cross-label="Footer - Language - It" data-wt-tr-event="navigation" href="https://it.comparis.ch/immobilien/marktplatz/details/show/23024420" hreflang="It" lang="It" rel="alternate">It</a>
# </li>
# <li>
# <a data-wt-cross-label="Footer - Language - En" data-wt-tr-event="navigation" href="https://en.comparis.ch/immobilien/marktplatz/details/show/23024420" hreflang="En" lang="En" rel="alternate">En</a>
# </li>
# </ul>
# </nav> </li>
# </ul>
# <ul class="nav-meta hide-for-medium header-nav-medium" data-nav-meta="">
# <li class="header-login">
# <a data-pc-href="https://www.comparis.ch/Authentication/Login?successUrl=%2fmycomparis%2fbereich%3fappCode%3dHF%26source%3d%252fimmobilien%252fmarktplatz%252fdetails%252fshow%252f23024420" data-pc-hrefcallback="framework.authentication.processHref" data-pc-windowtype="overlaydiv" data-rel="process" data-wt-cross-label="Header - Login" data-wt-tr-event="navigation" href="https://www.comparis.ch/mycomparis/bereich?appCode=HF&amp;source=%2fimmobilien%2fmarktplatz%2fdetails%2fshow%2f23024420" rel="nofollow"><span class="icn-circled">
# <i class="fa fa-user">
# </i>
# </span>Login</a>
# </li>
# <li class="hide-for-medium">
# <a class="menu-toggle navigation-medium" daca-ct-id="MenuButton" data-ct="true" data-ct-area="navigation" data-ct-subtype="Main" data-ct-type="Menu" data-menu-toggle="" href="#nav-main" id="ctautoid_482220850">
# <span class="bars"></span>
# <span class="show-for-sr">Navigation</span>
# </a>
# </li>
# </ul>
# <div class="langlist-is-visible header-tracking" data-lang-wrap="" id="lang">
# <nav>
# <ul class="nav-lang">
# <li class="active">
# <a data-wt-cross-label="Footer - Language - De" data-wt-tr-event="navigation" href="https://www.comparis.ch/immobilien/marktplatz/details/show/23024420" hreflang="De" lang="De" rel="alternate">De</a>
# </li>
# <li>
# <a data-wt-cross-label="Footer - Language - Fr" data-wt-tr-event="navigation" href="https://fr.comparis.ch/immobilien/marktplatz/details/show/23024420" hreflang="Fr" lang="Fr" rel="alternate">Fr</a>
# </li>
# <li>
# <a data-wt-cross-label="Footer - Language - It" data-wt-tr-event="navigation" href="https://it.comparis.ch/immobilien/marktplatz/details/show/23024420" hreflang="It" lang="It" rel="alternate">It</a>
# </li>
# <li>
# <a data-wt-cross-label="Footer - Language - En" data-wt-tr-event="navigation" href="https://en.comparis.ch/immobilien/marktplatz/details/show/23024420" hreflang="En" lang="En" rel="alternate">En</a>
# </li>
# </ul>
# </nav> </div>
# <div class="search-wrap" data-search-wrap="" id="search">
# <input class="st-default-search-input" data-searchfield="data-searchfield" placeholder="Suchen ..." type="text"/>
# </div>
# </div>
# </div>
# </div>
# <div class="head-top-fixed show-for-medium" id="head-for-medium">
# <div class="row">
# <div class="xsmall-12 medium-6 column">
# <a class="logo" href="/">
# <img alt="comparis.ch Logo" src="https://www.comparis.ch/img/logo/logo-comparis-homepage.png"/>
# </a>
# </div>
# <div class="xsmall-12 medium-6 column head-top-right">
# <a class="menu-toggle no-text-decoration" data-menu-toggle="" href="#nav-main">
# <ul class="header-menu-list">
# <li><span class="header-menu-text">Menü</span></li>
# <li><span class="bars"></span></li>
# </ul>
# </a>
# <ul class="nav-circled head-fixed-quicklinks">
# <li>
# <a data-search-focus="" href="#search">
# <i class="fa fa-search">
# </i>
# <span class="show-for-sr">Suche</span>
# </a>
# </li>
# <li>
# <a data-wt-cross-label="Header - Newsletter" data-wt-tr-event="navigation" href="https://www.comparis.ch/comparis/newsletter/subscribe">
# <span class=""><img class="header-icons" src="https://www.comparis.ch/img/headericons/envelope-solid.svg"/></span>
# </a>
# </li>
# <li>
# <a data-wt-cross-label="Header - Magazine" data-wt-tr-event="navigation" href="https://www.comparis.ch/magazin">
# <span class=""><img class="header-icons" src="https://www.comparis.ch/img/headericons/book-reader-solid.svg"/></span>
# </a>
# </li>
# <li>
# <a class="lang-toggle" data-lang-toggle-scroll="" id="lang-dropdown-scroll">
#
#                                                 DE
#                                                 <span>
# <i class="fa fa-angle-down">
# </i>
# </span>
# </a>
# </li>
# <li>
# <a data-pc-href="https://www.comparis.ch/Authentication/Login?successUrl=%2fmycomparis%2fbereich%3fappCode%3dHF%26source%3d%252fimmobilien%252fmarktplatz%252fdetails%252fshow%252f23024420" data-pc-hrefcallback="framework.authentication.processHref" data-pc-windowtype="overlaydiv" data-rel="process" data-wt-cross-label="Header - Login" data-wt-tr-event="navigation" href="https://www.comparis.ch/mycomparis/bereich?appCode=HF&amp;source=%2fimmobilien%2fmarktplatz%2fdetails%2fshow%2f23024420" rel="nofollow">
# <i class="fa fa-user">
# </i>
# </a>
# </li>
# </ul>
# <div class="langlist-is-visible-scroll header-tracking" data-lang-wrap="" id="langScroll">
# <nav>
# <ul class="nav-lang">
# <li class="active">
# <a data-wt-cross-label="Footer - Language - De" data-wt-tr-event="navigation" href="https://www.comparis.ch/immobilien/marktplatz/details/show/23024420" hreflang="De" lang="De" rel="alternate">De</a>
# </li>
# <li>
# <a data-wt-cross-label="Footer - Language - Fr" data-wt-tr-event="navigation" href="https://fr.comparis.ch/immobilien/marktplatz/details/show/23024420" hreflang="Fr" lang="Fr" rel="alternate">Fr</a>
# </li>
# <li>
# <a data-wt-cross-label="Footer - Language - It" data-wt-tr-event="navigation" href="https://it.comparis.ch/immobilien/marktplatz/details/show/23024420" hreflang="It" lang="It" rel="alternate">It</a>
# </li>
# <li>
# <a data-wt-cross-label="Footer - Language - En" data-wt-tr-event="navigation" href="https://en.comparis.ch/immobilien/marktplatz/details/show/23024420" hreflang="En" lang="En" rel="alternate">En</a>
# </li>
# </ul>
# </nav> </div>
# </div>
# </div>
# </div>
# </div>
# <nav class="nav-main-wrap" data-nav-main-wrap="">
# <div class="row">
# <ul class="nav-main" data-nav-main="data-nav-main" id="nav-main">
# <li class="has-submenu" data-has-submenu="data-has-submenu">
# <a data-ct="true" data-ct-area="navigation" data-ct-id="versicherungen" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Moving guide" data-wt-tr-event="navigation" href="https://www.comparis.ch/versicherung">
# <span>Versicherungen</span>
# </a>
# <div class="submenu-wrap">
# <a class="hide-for-medium drilldown-backlink" data-drilldown-backlink="data-drilldown-backlink">
# <i class="fa fa-angle-left">
# </i>
# Alle Themen</a>
# <div class="submenu row medium-uncollapse" data-is-submenu="data-is-submenu">
# <div class="xsmall-12 medium-4 column">
# <p class="h2">
# <a href="https://www.comparis.ch/versicherung">Versicherungen</a>
# </p>
# <ul>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="comparis 360 versicherungen" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Comparis 360" data-wt-tr-event="navigation" href="https://www.comparis.ch/360/Default?itm_source=comparis&amp;itm_medium=navimenu&amp;itm_campaign=c360-vers00-2017-de">NEU: Comparis 360</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="krankenkassen" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Health insurance" data-wt-tr-event="navigation" href="https://www.comparis.ch/krankenkassen/default">Krankenkasse</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="autoversicherung" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Car insurance" data-wt-tr-event="navigation" href="https://www.comparis.ch/autoversicherung/default">Autoversicherung</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="hausrat-versicherung" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Household Insurance" data-wt-tr-event="navigation" href="https://www.comparis.ch/hausrat-versicherung/default">Hausrat und Privathaftpflicht</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="motorradversicherung" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Motorcycle insurance" data-wt-tr-event="navigation" href="https://www.comparis.ch/motorradversicherung/default">Motorradversicherung</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="lebensversicherung" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Life Insurance" data-wt-tr-event="navigation" href="https://www.comparis.ch/leben/default">Lebensversicherung</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="rechtsschutz" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Legal Protection Insurance" data-wt-tr-event="navigation" href="https://www.comparis.ch/rechtsschutz/default">Rechtsschutz</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="tierversicherung" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Pet insurance" data-wt-tr-event="navigation" href="https://www.comparis.ch/tierversicherung/default">Tierversicherung</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="reiseversicherung" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Travel insurance" data-wt-tr-event="navigation" href="https://www.comparis.ch/reiseversicherung/default">Reiseversicherung</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="erdbebenversicherung" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Earthquake insurance" data-wt-tr-event="navigation" href="https://www.comparis.ch/erdbebenversicherung/default">Erdbebenversicherung</a>
# </li>
# </ul>
# </div>
# <div class="xsmall-12 medium-4 column">
# <div class="item-promo" data-item-promo="data-item-promo" data-wt-ec-ip-creative="NavigationPromotion" data-wt-ec-ip-name="Moving guide" data-wt-ec-ip-position="Main menu - Moving guide" data-wt-tr-event="promoBoxView"><p class="item-promo-title">Umzug oder Reinigung geplant?</p><p>Dann lehnen Sie sich entspannt zurück und lassen Sie uns die Arbeit machen.</p><ul class="check-list">
# <li><em class="fa fa-check"></em>Bis zu 5 Umzugsofferten</li>
# <li><em class="fa fa-check"></em>Individuell, kostenlos &amp; unverbindlich</li>
# <li><em class="fa fa-check"></em>Ohne Stress, Frust und Kosten</li>
# </ul><a class="button promo" data-ct="true" data-ct-area="navigation" data-ct-id="topmovers-2019_callout" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-tr-event="promoBoxClick" href="https://www.comparis.ch/immobilien/umzug/default">
# <strong>Jetzt Umzugsofferten anfordern</strong>
# </a></div>
# </div>
# </div>
# </div>
# </li>
# <li class="has-submenu" data-has-submenu="data-has-submenu">
# <a data-ct="true" data-ct-area="navigation" data-ct-id="auto und motorrad" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Vehicle advertisements" data-wt-tr-event="navigation" href="https://www.comparis.ch/inserate">
# <span>Auto &amp; Motorrad</span>
# </a>
# <div class="submenu-wrap">
# <a class="hide-for-medium drilldown-backlink" data-drilldown-backlink="data-drilldown-backlink">
# <i class="fa fa-angle-left">
# </i>
# Alle Themen</a>
# <div class="submenu row medium-uncollapse" data-is-submenu="data-is-submenu">
# <div class="xsmall-12 medium-4 column">
# <p class="h2">
# <a href="https://www.comparis.ch/inserate">Auto &amp; Motorrad</a>
# </p>
# <ul>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="automarkt" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Car Market" data-wt-tr-event="navigation" href="https://www.comparis.ch/carfinder/default">Automarkt</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="auto inserieren" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Sell Car" data-wt-tr-event="navigation" href="https://www.comparis.ch/carfinder/inserieren/default">Auto verkaufen</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="reifenmarkt" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Tyres Market" data-wt-tr-event="navigation" href="https://www.comparis.ch/preisvergleich/de/specials/reifen">Reifenmarkt</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="motorradmarkt" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Motorcycle Market" data-wt-tr-event="navigation" href="https://www.comparis.ch/motorrad/default">Motorradmarkt</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="motorrad inserieren" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Sell Motorcycle" data-wt-tr-event="navigation" href="https://www.comparis.ch/motorrad/inserieren/default">Motorrad verkaufen</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="fahrzeug  bewerten" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Valuation &amp; Selling" data-wt-tr-event="navigation" href="https://www.comparis.ch/carfinder/bewertung">Fahrzeug bewerten</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="leasing" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Car leasing" data-wt-tr-event="navigation" href="https://www.comparis.ch/leasing/default">Autoleasing</a>
# </li>
# </ul>
# </div>
# <div class="xsmall-12 medium-4 column">
# <div class="item-promo" data-item-promo="data-item-promo" data-wt-ec-ip-creative="NavigationPromotion" data-wt-ec-ip-name="Moving guide" data-wt-ec-ip-position="Main menu - Vehicle advertisements" data-wt-tr-event="promoBoxView"><p class="item-promo-title">Umzug oder Reinigung geplant?</p><p>Dann lehnen Sie sich entspannt zurück und lassen Sie uns die Arbeit machen.</p><ul class="check-list">
# <li><em class="fa fa-check"></em>Bis zu 5 Umzugsofferten</li>
# <li><em class="fa fa-check"></em>Individuell, kostenlos &amp; unverbindlich</li>
# <li><em class="fa fa-check"></em>Ohne Stress, Frust und Kosten</li>
# </ul><a class="button promo" data-ct="true" data-ct-area="navigation" data-ct-id="topmovers-2019_callout" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-tr-event="promoBoxClick" href="https://www.comparis.ch/immobilien/umzug/default">
# <strong>Jetzt Umzugsofferten anfordern</strong>
# </a></div>
# </div>
# </div>
# </div>
# </li>
# <li class="has-submenu" data-has-submenu="data-has-submenu">
# <a data-ct="true" data-ct-area="navigation" data-ct-id="immobilien und umzug" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Property" data-wt-tr-event="navigation" href="https://www.comparis.ch/wohnen">
# <span>Immobilien</span>
# </a>
# <div class="submenu-wrap">
# <a class="hide-for-medium drilldown-backlink" data-drilldown-backlink="data-drilldown-backlink">
# <i class="fa fa-angle-left">
# </i>
# Alle Themen</a>
# <div class="submenu row medium-uncollapse" data-is-submenu="data-is-submenu">
# <div class="xsmall-12 medium-4 column">
# <p class="h2">
# <a href="https://www.comparis.ch/wohnen">Immobilien</a>
# </p>
# <ul>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="marktplatz" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Property Market" data-wt-tr-event="navigation" href="https://www.comparis.ch/immobilien/default">Immobilienmarkt</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="inserieren" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Advertise Property" data-wt-tr-event="navigation" href="https://www.comparis.ch/immobilien/inserieren/default">Inserieren</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="immobilienverkauf" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Property sell" data-wt-tr-event="navigation" href="https://www.comparis.ch/immobilien/verkaufen">Immobilienverkauf</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="immobilienbewertung" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Property valuation" data-wt-tr-event="navigation" href="https://www.comparis.ch/immobilien/verkaufen/immobilie-bewerten">Immobilienbewertung</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="umzugsratgeber" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Moving guide" data-wt-tr-event="navigation" href="https://www.comparis.ch/immobilien/umzug/default">Umzugsratgeber</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="quellensteuer" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Withholding tax" data-wt-tr-event="navigation" href="https://www.comparis.ch/steuern/quellensteuerrechner/default">Quellensteuer</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="steuervergleich" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Tax Comparison" data-wt-tr-event="navigation" href="https://www.comparis.ch/steuern/steuervergleich/default">Steuervergleich</a>
# </li>
# </ul>
# </div>
# <div class="xsmall-12 medium-4 column">
# <div class="item-promo" data-item-promo="data-item-promo" data-wt-ec-ip-creative="NavigationPromotion" data-wt-ec-ip-name="Moving guide" data-wt-ec-ip-position="Main menu - Property" data-wt-tr-event="promoBoxView"><p class="item-promo-title">Umzug oder Reinigung geplant?</p><p>Dann lehnen Sie sich entspannt zurück und lassen Sie uns die Arbeit machen.</p><ul class="check-list">
# <li><em class="fa fa-check"></em>Bis zu 5 Umzugsofferten</li>
# <li><em class="fa fa-check"></em>Individuell, kostenlos &amp; unverbindlich</li>
# <li><em class="fa fa-check"></em>Ohne Stress, Frust und Kosten</li>
# </ul><a class="button promo" data-ct="true" data-ct-area="navigation" data-ct-id="topmovers-2019_callout" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-tr-event="promoBoxClick" href="https://www.comparis.ch/immobilien/umzug/default">
# <strong>Jetzt Umzugsofferten anfordern</strong>
# </a></div>
# </div>
# </div>
# </div>
# </li>
# <li class="has-submenu" data-has-submenu="data-has-submenu">
# <a data-ct="true" data-ct-area="navigation" data-ct-id="kredit und konto" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Loans &amp; Mortgages" data-wt-tr-event="navigation" href="https://www.comparis.ch/finanzen">
# <span>Kredit &amp; Hypotheken</span>
# </a>
# <div class="submenu-wrap">
# <a class="hide-for-medium drilldown-backlink" data-drilldown-backlink="data-drilldown-backlink">
# <i class="fa fa-angle-left">
# </i>
# Alle Themen</a>
# <div class="submenu row medium-uncollapse" data-is-submenu="data-is-submenu">
# <div class="xsmall-12 medium-4 column">
# <p class="h2">
# <a href="https://www.comparis.ch/finanzen">Kredit &amp; Hypotheken</a>
# </p>
# <ul>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="privatkredit" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Private loan" data-wt-tr-event="navigation" href="https://www.comparis.ch/privatkredit/default">Privatkredit</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="hypotheken" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Mortgages" data-wt-tr-event="navigation" href="https://www.comparis.ch/hypotheken/default">Hypotheken</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="bonitaetsauskunft" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Credit Score" data-wt-tr-event="navigation" href="https://www.comparis.ch/bonitaetsauskunft/default">Bonitätsauskunft</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="kreditkarten" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Credit cards" data-wt-tr-event="navigation" href="https://www.comparis.ch/kreditkarten/default">Kreditkarten</a>
# </li>
# </ul>
# </div>
# <div class="xsmall-12 medium-4 column">
# <div class="item-promo" data-item-promo="data-item-promo" data-wt-ec-ip-creative="NavigationPromotion" data-wt-ec-ip-name="Moving guide" data-wt-ec-ip-position="Main menu - Loans &amp; Mortgages" data-wt-tr-event="promoBoxView"><p class="item-promo-title">Umzug oder Reinigung geplant?</p><p>Dann lehnen Sie sich entspannt zurück und lassen Sie uns die Arbeit machen.</p><ul class="check-list">
# <li><em class="fa fa-check"></em>Bis zu 5 Umzugsofferten</li>
# <li><em class="fa fa-check"></em>Individuell, kostenlos &amp; unverbindlich</li>
# <li><em class="fa fa-check"></em>Ohne Stress, Frust und Kosten</li>
# </ul><a class="button promo" data-ct="true" data-ct-area="navigation" data-ct-id="topmovers-2019_callout" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-tr-event="promoBoxClick" href="https://www.comparis.ch/immobilien/umzug/default">
# <strong>Jetzt Umzugsofferten anfordern</strong>
# </a></div>
# </div>
# </div>
# </div>
# </li>
# <li class="has-submenu" data-has-submenu="data-has-submenu">
# <a data-ct="true" data-ct-area="navigation" data-ct-id="preisvergleich" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Price comparison" data-wt-tr-event="navigation" href="https://www.comparis.ch/preisvergleich/">
# <span>Preisvergleich</span>
# </a>
# <div class="submenu-wrap">
# <a class="hide-for-medium drilldown-backlink" data-drilldown-backlink="data-drilldown-backlink">
# <i class="fa fa-angle-left">
# </i>
# Alle Themen</a>
# <div class="submenu row medium-uncollapse" data-is-submenu="data-is-submenu">
# <div class="xsmall-12 medium-8 column">
# <p class="h2">
# <a href="https://www.comparis.ch/preisvergleich/">Preisvergleich</a>
# </p>
# <div class="navSubMenuSearchHolder">
# <p class="navSubMenuTitle">Was suchen Sie:</p>
# <div class="row collapse">
# <input class="navSubMenuSearchInput" id="navSubMenuSearchInput" onkeypress="navSubMenuSearchValidate()" placeholder="Produktname"/>
# <span class="navSubMenuSearchInputIcon" id="navSubMenuSearchButton" lang="de" onclick="navSubMenuSearch()">
# <i class="fa fa-search" style="padding:10px">
# </i>
# </span>
# </div>
# <p class="navSubMenuTitle">Zu den Kategorien</p>
# </div>
# <ul class="navSubMenuTwoColumnList">
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="baby und kind" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Baby and child" data-wt-tr-event="navigation" href="https://www.comparis.ch/preisvergleich/de/baby-kind-c787">Baby und Kind</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="beauty und wellness" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Beauty and wellness" data-wt-tr-event="navigation" href="https://www.comparis.ch/preisvergleich/de/beauty-wellness-c425">Beauty und Wellness</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="buero und schreibwaren" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Office and stationary suppplies" data-wt-tr-event="navigation" href="https://www.comparis.ch/preisvergleich/de/buero-schreibwaren-c841">Büro und Schreibwaren</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="computer und software" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Computer and software" data-wt-tr-event="navigation" href="https://www.comparis.ch/preisvergleich/de/computer-software-c19">Computer und Software</a>
# </li>
# <li>
# <a data-ct="true" data-ct-area="navigation" data-ct-id="elektronik" data-ct-subtype="Main" data-ct-target="Internal" data-ct-type="Menu" data-wt-cross-label="Main menu - Electronics" data-wt-tr-event="navigation" href="https://www.comparis.ch/preisvergleich/de/elektronik-c882">Elektronik</a>
# </li>
# <li>
# ...
# <img onerror="this.onerror = null; this.src='/immobilien/resources/images/DE_placeholderimage_property-400x300.png';" src="https://assets.comparis.ch/image/upload/s--MszNwLKh--/c_fill,f_auto,h_458,q_auto,w_610/v1/immobilien/Images/DataCollect/0b61e7e8-7008-79cb-2bb4-75a197f682e6.jpg" title="Doppelgaragenhälfte"/>
# </a>
# <article class="spacer-bottom">
# <h4>
# <a data-wt-fa-label="Click - Related Property" data-wt-partnername="Anibis" data-wt-propertyprice="undefined" data-wt-propertysize="undefined" data-wt-propertytype="1" data-wt-rentorbuy="Rent" data-wt-status="undefined" data-wt-tr-event="funnelAction" href="/immobilien/marktplatz/details/show/22359226" rel="nofollow">
#                 Doppelgaragenhälfte
#             </a>
# </h4>
# <ul>
# <li><b>Einzelgarage</b></li>
# </ul>
# <a data-wt-fa-label="Click - Related Property" data-wt-partnername="Anibis" data-wt-propertyprice="undefined" data-wt-propertysize="undefined" data-wt-propertytype="1" data-wt-rentorbuy="Rent" data-wt-status="undefined" data-wt-tr-event="funnelAction" href="/immobilien/marktplatz/details/show/22359226" rel="nofollow">Mehr</a>
# </article>
# <div class="entry-footer-wrapper">
# <section class="entry-footer">
# <div class="item-price large pull-right">
# <span>CHF</span>
# <strong>100</strong>
# </div>
# </section>
# <section class="entry-footer-meta-info meta-small">
#             05.11.2019
#         </section>
# </div>
# </div>
# </div>
# <div class="column">
# <div class="entry" data-equalizer-watch="">
# <a data-wt-fa-label="Click - Related Property" data-wt-partnername="Anibis" data-wt-propertyprice="undefined" data-wt-propertysize="undefined" data-wt-propertytype="1" data-wt-rentorbuy="Rent" data-wt-status="undefined" data-wt-tr-event="funnelAction" href="/immobilien/marktplatz/details/show/22424804" rel="nofollow">
# <img onerror="this.onerror = null; this.src='/immobilien/resources/images/DE_placeholderimage_property-400x300.png';" src="https://assets.comparis.ch/image/upload/s--jq3aze_M--/c_fill,f_auto,h_458,q_auto,w_610/v1/immobilien/Images/DataCollect/99f2e9b0-645b-d1c0-d2ca-27c925b445e3.jpg" title="Moderne Praxisräumlichkeiten zu vermieten"/>
# </a>
# <article class="spacer-bottom">
# <h4>
# <a data-wt-fa-label="Click - Related Property" data-wt-partnername="Anibis" data-wt-propertyprice="undefined" data-wt-propertysize="undefined" data-wt-propertytype="1" data-wt-rentorbuy="Rent" data-wt-status="undefined" data-wt-tr-event="funnelAction" href="/immobilien/marktplatz/details/show/22424804" rel="nofollow">
#                 Moderne Praxisräumlichkeiten zu vermieten
#             </a>
# </h4>
# <ul>
# <li><b>Gewerbeobjekt</b></li>
# <li>1. Etage</li>
# </ul>
# <a data-wt-fa-label="Click - Related Property" data-wt-partnername="Anibis" data-wt-propertyprice="undefined" data-wt-propertysize="undefined" data-wt-propertytype="1" data-wt-rentorbuy="Rent" data-wt-status="undefined" data-wt-tr-event="funnelAction" href="/immobilien/marktplatz/details/show/22424804" rel="nofollow">Mehr</a>
# </article>
# <div class="entry-footer-wrapper">
# <section class="entry-footer">
# <div class="item-price large pull-right">
# <span>CHF</span>
# <strong>850</strong>
# </div>
# </section>
# <section class="entry-footer-meta-info meta-small">
#             15.11.2019
#         </section>
# </div>
# </div>
# </div>
# <div class="column column hide-for-small-only">
# <div class="entry" data-equalizer-watch="">
# <a data-wt-fa-label="Click - Related Property" data-wt-partnername="Anibis" data-wt-propertyprice="undefined" data-wt-propertysize="undefined" data-wt-propertytype="1" data-wt-rentorbuy="Rent" data-wt-status="undefined" data-wt-tr-event="funnelAction" href="/immobilien/marktplatz/details/show/22380112" rel="nofollow">
# <img onerror="this.onerror = null; this.src='/immobilien/resources/images/DE_placeholderimage_property-400x300.png';" src="https://assets.comparis.ch/image/upload/s--bH6A7cvc--/c_fill,f_auto,h_458,q_auto,w_610/v1/immobilien/Images/DataCollect/a2eb0869-e974-2faf-be0e-dc9e3c2f7d25.jpg" title="Dachgeschosswohnung - heimelig und modern"/>
# </a>
# <article class="spacer-bottom">
# <h4>
# <a data-wt-fa-label="Click - Related Property" data-wt-partnername="Anibis" data-wt-propertyprice="undefined" data-wt-propertysize="undefined" data-wt-propertytype="1" data-wt-rentorbuy="Rent" data-wt-status="undefined" data-wt-tr-event="funnelAction" href="/immobilien/marktplatz/details/show/22380112" rel="nofollow">
#                 Dachgeschosswohnung - heimelig und modern
#             </a>
# </h4>
# <ul>
# <li><b>Wohnung</b></li>
# <li>3½ Zimmer</li>
# <li>69 m²</li>
# <li>4. Etage</li>
# </ul>
# <a data-wt-fa-label="Click - Related Property" data-wt-partnername="Anibis" data-wt-propertyprice="undefined" data-wt-propertysize="undefined" data-wt-propertytype="1" data-wt-rentorbuy="Rent" data-wt-status="undefined" data-wt-tr-event="funnelAction" href="/immobilien/marktplatz/details/show/22380112" rel="nofollow">Mehr</a>
# </article>
# <div class="entry-footer-wrapper">
# <section class="entry-footer">
# <div class="item-price large pull-right">
# <span>CHF</span>
# <strong>1'200</strong>
# </div>
# </section>
# <section class="entry-footer-meta-info meta-small">
#             17.09.2019
#         </section>
# </div>
# </div>
# </div>
# <div class="column">
# <div class="entry" data-equalizer-watch="">
# <a data-wt-fa-label="Click - Related Property" data-wt-partnername="Anibis" data-wt-propertyprice="undefined" data-wt-propertysize="undefined" data-wt-propertytype="1" data-wt-rentorbuy="Rent" data-wt-status="undefined" data-wt-tr-event="funnelAction" href="/immobilien/marktplatz/details/show/23024537" rel="nofollow">
# <img onerror="this.onerror = null; this.src='/immobilien/resources/images/DE_placeholderimage_property-400x300.png';" src="/immobilien/api/image/getdirect?guid=cbea4d6c-8a4f-4eb6-8cb8-eb59591feff2&amp;w=610&amp;h=458&amp;rm=3" title="2 appartements 4,5 et 3,5 pièces à Bex"/>
# </a>
# <article class="spacer-bottom">
# <h4>
# <a data-wt-fa-label="Click - Related Property" data-wt-partnername="Anibis" data-wt-propertyprice="undefined" data-wt-propertysize="undefined" data-wt-propertytype="1" data-wt-rentorbuy="Rent" data-wt-status="undefined" data-wt-tr-event="funnelAction" href="/immobilien/marktplatz/details/show/23024537" rel="nofollow">
#                 2 appartements 4,5 et 3,5 pièces à Bex
#             </a>
# </h4>
# <ul>
# <li><b>Wohnung</b></li>
# </ul>
# <a data-wt-fa-label="Click - Related Property" data-wt-partnername="Anibis" data-wt-propertyprice="undefined" data-wt-propertysize="undefined" data-wt-propertytype="1" data-wt-rentorbuy="Rent" data-wt-status="undefined" data-wt-tr-event="funnelAction" href="/immobilien/marktplatz/details/show/23024537" rel="nofollow">Mehr</a>
# </article>
# <div class="entry-footer-wrapper">
# <section class="entry-footer">
# <div class="item-price large pull-right">
# <strong>Auf Anfrage</strong>
# </div>
# </section>
# <section class="entry-footer-meta-info meta-small">
#             26.02.2020
#         </section>
# </div>
# </div>
# </div>
# </div> </div>
# </div>
# <div class="reveal large" data-reveal="" id="contact-area-lightbox-container-wrapper" style="padding: 0">
# <div id="contact-area-lightbox-container"></div>
# <button aria-label="Close" class="close-button" data-close="" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# </div>
# <!-- CRITEO Tracker -->
# <!-- END CRITEO Tracker -->
# </div></div></div></section>
# <!-- UIIntegrated -->
# </div>
# <!-- end .content-wrap -->
# <div class="footer-all no-print" data-footer-all="" id="footer"><div class="pre-footer" role="complementary">
# </div>
# <footer class="footer">
# <!-- end .footer-navbar -->
# <div class="footer-local" role="complementary">
# <div class="row">
# <div class="xsmall-12 small-4 medium-4 column footer-links">
# <p class="h5">comparis.ch</p>
# <ul class="arrow-list">
# <li>
# <a data-wt-cross-label="Footer - Ueber Comparis" data-wt-tr-event="navigation" href="https://www.comparis.ch/ueber-comparis">Über Comparis</a>
# </li>
# <li>
# <a data-wt-cross-label="Footer - Medien" data-wt-tr-event="navigation" href="https://www.comparis.ch/comparis/press/default">Medien</a>
# </li>
# <li>
# <a data-wt-cross-label="Footer - Karriere" data-wt-tr-event="navigation" href="https://www.comparis.ch/comparis/karriere/jobs">Karriere</a>
# </li>
# </ul>
# </div>
# <div class="xsmall-12 small-5 medium-4 column" data-footersocialmedia="">
# <p class="h5">Folgen Sie uns</p>
# <ul class="nav-circled">
# <li>
# <a data-wt-cross-label="Footer - Facebook" data-wt-tr-event="navigation" href="https://www.facebook.com/comparis.ch" target="_blank" title="Comparis auf Facebook">
# <i class="fa fa-facebook">
# </i>
# </a>
# </li>
# <li>
# <a data-wt-cross-label="Footer - Instagram" data-wt-tr-event="navigation" href="https://www.instagram.com/comparis_ch/" target="_blank" title="Comparis auf Instagram">
# <i class="fa fa-instagram">
# </i>
# </a>
# </li>
# <li>
# <a data-wt-cross-label="Footer - YouTube" data-wt-tr-event="navigation" href="https://www.youtube.com/comparis" target="_blank" title="Comparis auf YouTube">
# <i class="fa fa-youtube">
# </i>
# </a>
# </li>
# <li>
# <a data-wt-cross-label="Footer - LinkedIn" data-wt-tr-event="navigation" href="https://www.linkedin.com/company/comparis.ch-ag" target="_blank" title="Comparis auf LinkedIn">
# <i class="fa fa-linkedin">
# </i>
# </a>
# </li>
# <li>
# <a data-wt-cross-label="Footer - Twitter" data-wt-tr-event="navigation" href="https://twitter.com/comparis" target="_blank" title="Comparis auf Twitter">
# <i class="fa fa-twitter">
# </i>
# </a>
# </li>
# <li>
# <a class="hide-for-small" data-wt-cross-label="Footer - Snapchat" data-wt-tr-event="navigation" href="https://www.snapchat.com/add/comparis.ch" target="_blank" title="Comparis auf  Snapchat">
# <i class="fa fa-snapchat-ghost">
# </i>
# </a>
# </li>
# </ul>
# </div>
# <div class="xsmall-12 small-3 medium-4 column" data-footerlang="">
# <p class="h5">Sprache</p>
# <nav>
# <ul class="nav-lang">
# <li class="active">
# <a data-wt-cross-label="Footer - Language - De" data-wt-tr-event="navigation" href="https://www.comparis.ch/immobilien/marktplatz/details/show/23024420" hreflang="De" lang="De" rel="alternate">De</a>
# </li>
# <li>
# <a data-wt-cross-label="Footer - Language - Fr" data-wt-tr-event="navigation" href="https://fr.comparis.ch/immobilien/marktplatz/details/show/23024420" hreflang="Fr" lang="Fr" rel="alternate">Fr</a>
# </li>
# <li>
# <a data-wt-cross-label="Footer - Language - It" data-wt-tr-event="navigation" href="https://it.comparis.ch/immobilien/marktplatz/details/show/23024420" hreflang="It" lang="It" rel="alternate">It</a>
# </li>
# <li>
# <a data-wt-cross-label="Footer - Language - En" data-wt-tr-event="navigation" href="https://en.comparis.ch/immobilien/marktplatz/details/show/23024420" hreflang="En" lang="En" rel="alternate">En</a>
# </li>
# </ul>
# </nav> </div>
# </div>
# </div>
# <!-- end .footer-local -->
# <div class="footer-global" role="contentinfo">
# <div class="row">
# <div class="xsmall-12 small-12 small-pull-3 column">
# <ul class="nav-footer-global">
# <li>
# <a data-wt-cross-label="Footer - Kontakt" data-wt-tr-event="navigation" href="https://www.comparis.ch/comparis/info/kontakt" title="nofollow">Kontakt</a>
# </li>
# <li>
# <a data-wt-cross-label="Footer - Datenschutz" data-wt-tr-event="navigation" href="https://www.comparis.ch/comparis/info/privacy" rel="nofollow">Datenschutz</a>
# </li>
# <li>
# <a data-wt-cross-label="Footer - Rechtliche Informationen" data-wt-tr-event="navigation" href="https://www.comparis.ch/comparis/info/legal" rel="nofollow">Rechtliche Informationen</a>
# </li>
# <li>
# <a data-wt-cross-label="Footer - Impressum" data-wt-tr-event="navigation" href="https://www.comparis.ch/comparis/press/impressum" rel="nofollow">Impressum</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="row">
# <div class="xsmall-12 column">
# <p class="copy">© 1996–2020 comparis.ch AG, Birmensdorferstrasse 108, 8003 Zürich, +41 44 360 52 62</p>
# </div>
# </div>
# </div><!-- end .footer-global -->
# </footer><!-- end .footer -->
# </div>
# <!-- end .footer-all -->
# <div class="highlight-overlay hide-for-medium" data-overlay=""></div>
# <div class="hide">
# <div class="reveal" data-reveal="" id="authoverlay">
# <form action="/authentication/login" data-auth-url="action" method="post"><div class="row">
# <div class="small-12 medium-6 columns">
# <div class="main-title text-dark-green reduce-szie-for-small reduce-size-for-xsmall">Login</div>
# </div>
# </div>
# <div class="row">
# <div class="input-group xsmall-12 columns">
# <label for="AuthemticationEmail">E-Mail-Adresse</label><input data-val="true" data-val-required="Bitte E-Mail-Adresse eingeben" id="AuthemticationEmail" name="AuthemticationEmail" type="text"/><div class="is-valid form-error" style="display: inline"></div> </div>
# </div>
# <div class="row">
# <div class="input-group xsmall-12 columns">
# <label for="Password">Passwort</label><input autocomplete="off" data-val="true" data-val-required="Bitte Passwort eingeben" id="Password" name="Password" type="password"/><div class="is-valid form-error" style="display: inline"></div> </div>
# </div>
# <div class="row authentication-response">
# <div class="column">
# <div class="is-valid form-error" style="display: inline"></div>
# </div>
# </div>
# <div class="row right">
# <div class="xsmall-12 columns">
# <a class="button secondary" data-auth-url="href" data-rel="process-close" data-role="button" href="#">Abbrechen</a>
# <button class="button" type="submit">Login</button>
# </div>
# </div>
# <br/>
# <p>
#     Sie sind ein neuer Benutzer:
#     <a data-auth-url="href" href="https://www.comparis.ch/authentication/register?introText=">Registrieren</a>
# </p>
# <p>
# <a href="https://www.comparis.ch/authentication/restorepasswordrequest">Passwort vergessen?</a>
# </p></form>
# </div>
# </div>
# <!-- begin: GoogleAnalyticsTracker Tag -->
# <script type="text/javascript">(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                               (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                               m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#                               })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#                                 // Init mapping table for ga dimensions
#                               (function(){
#                                 var mapper = comparis.require('framework.tracking.processor.ga.parameterMapper');
#                                 mapper.addDimension('pv-env','1');
# mapper.addDimension('pv-os','2');
# mapper.addDimension('pv-dev','3');
# mapper.addDimension('pv-req','4');
# mapper.addDimension('pv-view','5');
# mapper.addDimension('pv-window','22');
# mapper.addDimension('raw-url','6');
# mapper.addDimension('qrystr','7');
# mapper.addDimension('mc_id','9');
# mapper.addDimension('extclient','10');
# mapper.addDimension('um_usertrackingcookiegid','11');
# mapper.addDimension('um_sessionid','12');
# mapper.addDimension('splittestingConfig','19');
# mapper.addDimension('recognitionState','18');
# mapper.addDimension('kaufen-miete','13');
# mapper.addDimension('ct-area','15');
# mapper.addDimension('ct-id','14');
# mapper.addDimension('ct-target','16');
# mapper.addDimension('partner_names','17');
# mapper.addDimension('advertisementLoaded','20');
# mapper.addDimension('partialViewsLoaded','21');
# mapper.addDimension('contactGuid','23');
# mapper.addMetric('numberOfContacts','1');
#
#                                 }());
#
#                               ga('create', 'UA-55460714-2', 'auto', {'siteSpeedSampleRate': 1});
#                               ga('require', 'linkid', 'linkid.js');
#
# </script>
# <!-- end: GoogleAnalyticsTracker Tag -->
# <!-- begin: JavaScript Tracker -->
# <script type="text/javascript">
#                 comparis.require('framework.xmlHttpRequest').sendAsync('/comparis/Tracking/JsLog');
# </script>
# <!-- end: JavaScript Tracker -->
# <!-- begin: UptrendsRUMtracker tag -->
# <script type="text/javascript">
# </script>
# <!-- end: UptrendsRUMtracker tag -->
# <script type="text/javascript">
# comparis.require('extlib.jQuery')(document).bind('comparis-initLegacyModules',function () {
# });
# comparis.require('framework.eventQueue').startEventQueue();
# </script>
# </body>
# </html>

# %%
nr = int(url2[-8:])
nr
# Out:
# 23024420

# %%
source =pd.DataFrame.from_dict({'city': city, 'DateofScrapping': '26.02.2020'}, orient='index', columns = [nr] )
source
# Out:
#                    23024420
# city                   Bern
# DateofScrapping  26.02.2020

# %% [markdown]
# #### 2.2.1  Adress and Date of Publication

# %%
###

"""
<h3 class="text-green">Riedbachstrasse 80, 3027 Bern</h3>

"""
adress_soup = soup2.find_all('h3', attrs = {'class':'text-green'})
if len(adress_soup)==0:
    adress = {'adress': 'NaN'}
else:
    adress = {'adress': adress_soup[0].text}
adress
adress = pd.DataFrame.from_dict(adress, orient='index', columns = [nr] )
adress
# Out:
#                           23024420
# adress  Freiburgstr. 62, 3008 Bern

# %%
#Date of Publication

"""
<div class="row xsmall-12 columns">
        <ul class="meta-tag-line">
            <li>
                Erstmals gefunden am 26.02.2020
            </li>
        </ul>
    </div>
"""

publication={}
publication_soup = soup2.find_all('div', attrs = {'class':'row xsmall-12 columns'})
for element in publication_soup:
    for x in element.find_all('li'):
        publication['publication_date']=(x.text.replace('\r\n','').replace('Erstmals gefunden am ','').replace('\r\n','').replace(" ",''))
publication
publication_date = pd.DataFrame.from_dict(publication, orient='index', columns = [nr] )
publication_date
# Out:
#                     23024420
# publication_date  26.02.2020

# %% [markdown]
# #### (##2.2.2  Overview (First large table)##)

# %%
## Overview from one flat --> not used?
overview=[]
overview_soup = soup2.find_all('div', attrs = {'class':'item-price large'})
for element in overview_soup:
    for x in element.find_all('strong'):
        overview.append(x.text)
overview
# Out:
# ['Wohnung', 'CHF 890', '1½', '30 m²', 'ca. CHF 112 /Jahr']

# %% [markdown]
# #### 2.2.3 Ratings

# %%
#### rating
"""
<div class="info-grid-content">
                    <span class="item-rating medium">
                        <strong>
                            <i class="text-green icon-comparis-points" data-icon="data-icon">
</i> 4
                        </strong>
                    </span>
                </div>
"""
rating_soup = soup2.find_all('span', attrs = {'class':'item-rating medium'})
if len(rating_soup)==0:
    rating = {'rating': 'NaN'}
else:
    rating = {'rating': re.findall('[0-9]',rating_soup[0].text)[0]}
rating
rating = pd.DataFrame.from_dict(rating, orient='index', columns = [nr] )
rating
# Out:
#        23024420
# rating      NaN

# %%
rating_soup
# Out:
# []

# %% [markdown]
# #### 2.2.4 Detailed overview (second smaller table)

# %%
infos_soup = soup2.find_all('dl')

### Categorie name
info1=[]
for x in infos_soup[0].find_all('dt'):
    info1.append(x.text.replace(" ","").replace("\r\n",""))

info1

### actual info

info2=[]
for x in infos_soup[0].find_all('dd'):
    info2.append(x.text.replace('\r\n','').replace('CHF','').replace(' ','').replace('\n\n', '1').replace("'","").replace("m²","").replace('½','.5'))

info2

info={}
for x in range(len(info2)):
    info[info1[x]] = info2[x]

info = pd.DataFrame.from_dict(info, orient='index', columns = [nr] )
info
# Out:
#                      23024420
# Objektart             Wohnung
# MietpreisproMonat         890
# Wohnfläche                 30
# Zimmer                    1.5
# Verfügbarab        01.05.2020

# %% [markdown]
# ##### 2.6 to one column

# %%
ds=pd.concat([info, rating, adress, publication_date, source])

# %%
ds = ds.transpose()
ds
# Out:
#          Objektart MietpreisproMonat Wohnfläche Zimmer Verfügbarab rating  \
# 23024420   Wohnung               890         30    1.5  01.05.2020    NaN
#
#                               adress publication_date  city DateofScrapping
# 23024420  Freiburgstr. 62, 3008 Bern       26.02.2020  Bern      26.02.2020

# %% [markdown]
# # 3. Repeat for other flats

# %%
## repeat in a loop with all url
for x in link:
    print(x)
# Out:
# /immobilien/marktplatz/details/show/23024420
# /immobilien/marktplatz/details/show/23024399
# /immobilien/marktplatz/details/show/23024131
# /immobilien/marktplatz/details/show/23023616

# %%
link=linkBern[1:]
link
# Out:
# ['https://www.comparis.ch/immobilien/marktplatz/details/show/23024399',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23024131',
#  'https://www.comparis.ch/immobilien/marktplatz/details/show/23023616']

# %%
## repeat in a loop with all url
for x in link:
    print(x)
    # get soup (2.1):
    html2 = requests.get(x).content
    soup2 = BeautifulSoup(html2, "lxml")
    nr = int(x[-8:])   
    # get id:
    nr = int(x[-8:])
    ## city and date of webscrapping
    source =pd.DataFrame.from_dict({'city': city, 'DateofScrapping': '26.02.2020'}, orient='index', columns = [nr] )
    
    # adress:
    adress_soup = soup2.find_all('h3', attrs = {'class':'text-green'})
    if len(adress_soup)==0:
        adress = {'adress': 'NaN'}
    else:
        adress = {'adress': adress_soup[0].text}
    adress = pd.DataFrame.from_dict(adress, orient='index', columns = [nr] )

    #publication Date:
    publication={}
    publication_soup = soup2.find_all('div', attrs = {'class':'row xsmall-12 columns'})
    for element in publication_soup:
        for x in element.find_all('li'):
            publication['publication_date']=(x.text.replace('\r\n','').replace('Erstmals gefunden am ','').replace('\r\n','').replace(" ",''))
    publication_date = pd.DataFrame.from_dict(publication, orient='index', columns = [nr] )
    
    
    # rating: 
    rating_soup = soup2.find_all('span', attrs = {'class':'item-rating medium'})
    if len(rating_soup)==0:
        rating = {'rating': 'NaN'}
    else:
        rating = {'rating': re.findall('[0-9]',rating_soup[0].text)[0]}
    rating = pd.DataFrame.from_dict(rating, orient='index', columns = [nr] )

    
    # details: 
    infos_soup = soup2.find_all('dl')
    # Categorie name
    info1=[]
    for x in infos_soup[0].find_all('dt'):
        info1.append(x.text.replace(" ","").replace("\r\n",""))
    # actual info
    info2=[]
    for x in infos_soup[0].find_all('dd'):
        info2.append(x.text.replace('\r\n','').replace('CHF','').replace(' ','').replace('\n\n', '1').replace("'","").replace("m²","").replace('½','.5'))
    info={}
    for x in range(len(info2)):
        info[info1[x]] = info2[x]
    info = pd.DataFrame.from_dict(info, orient='index', columns = [nr] )
    
    #row
    row =pd.concat([info, rating, adress, publication_date, source])
    row = row.transpose()
    # merge with dataset
    ds=pd.concat([ds, row], sort=False)
# Out:
# https://www.comparis.ch/immobilien/marktplatz/details/show/23024131

# %%
ds
# Out:
# C:\Users\haenni\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#          Balkon(e) Baujahr DateofScrapping Einstellplatz Geschoss  \
# 23024420       NaN     NaN      26.02.2020           NaN      NaN
# 23024131         1    2013      26.02.2020             1  2.Stock
#
#          Haustiereerlaubt Kabel-TV Lift MietpreisproMonat  \
# 23024420              NaN      NaN  NaN               890
# 23024131                1        1    1              1490
#
#          MietpreisproMonat(exkl.NK) Minergie-zertifiziert Nebenkosten  \
# 23024420                        NaN                   NaN         NaN
# 23024131                       1310                     1         180
#
#          Objektart Verfügbarab Wohnfläche Zimmer  \
# 23024420   Wohnung  01.05.2020         30    1.5
# 23024131   Wohnung  01.06.2020         59    2.5
#
#                                  adress  city publication_date rating
# 23024420     Freiburgstr. 62, 3008 Bern  Bern       26.02.2020    NaN
# 23024131  Riedbachstrasse 80, 3027 Bern  Bern       26.02.2020      4

# %%
ds
# Out:
#          Balkon(e) Baujahr DateofScrapping Einstellplatz Geschoss  \
# 23024420       NaN     NaN      26.02.2020           NaN      NaN
# 23024131         1    2013      26.02.2020             1  2.Stock
#
#          Haustiereerlaubt Kabel-TV Lift MietpreisproMonat  \
# 23024420              NaN      NaN  NaN               890
# 23024131                1        1    1              1490
#
#          MietpreisproMonat(exkl.NK) Minergie-zertifiziert Nebenkosten  \
# 23024420                        NaN                   NaN         NaN
# 23024131                       1310                     1         180
#
#          Objektart Verfügbarab Wohnfläche Zimmer  \
# 23024420   Wohnung  01.05.2020         30    1.5
# 23024131   Wohnung  01.06.2020         59    2.5
#
#                                  adress  city publication_date rating
# 23024420     Freiburgstr. 62, 3008 Bern  Bern       26.02.2020    NaN
# 23024131  Riedbachstrasse 80, 3027 Bern  Bern       26.02.2020      4

# %%
row
# Out:
#          Objektart MietpreisproMonat MietpreisproMonat(exkl.NK) Nebenkosten  \
# 23024131   Wohnung              1490                       1310         180
#
#          Wohnfläche Zimmer Geschoss Baujahr Verfügbarab Balkon(e)  \
# 23024131         59    2.5  2.Stock    2013  01.06.2020         1
#
#          Einstellplatz Lift Haustiereerlaubt Kabel-TV Minergie-zertifiziert  \
# 23024131             1    1                1        1                     1
#
#          rating                         adress publication_date  city  \
# 23024131      4  Riedbachstrasse 80, 3027 Bern       26.02.2020  Bern
#
#          DateofScrapping
# 23024131      26.02.2020

# %%
# merge

# %%
### add a colum for the date of werbscrabing
### add colum for the city

# %%
## 3.3 save to csv
