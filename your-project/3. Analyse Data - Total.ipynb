# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline
sns.set()

# %%
total = pd.read_csv('Data_clean/total_clean.csv', index_col=0)
total.head()
# Out:
#    Year  Diabetes %  Malnutrition %  Cancer stomach %  Cancer oral %  \
# 0  1990    0.020502        0.000543          0.023293       0.005997
# 1  1991    0.020827        0.000551          0.023056       0.006229
# 2  1992    0.020463        0.000605          0.022643       0.006403
# 3  1993    0.020526        0.000597          0.021860       0.006436
# 4  1994    0.020114        0.000586          0.021549       0.006501
#
#    Cancer oesophagus %  Cancer colon %  All Sugar forms pp  \
# 0             0.005803        0.029806          575.897851
# 1             0.005895        0.030265          498.094109
# 2             0.005940        0.031023          483.049942
# 3             0.006039        0.031147          490.105317
# 4             0.006135        0.031762          431.864656
#
#    Fruits & Veggies pp  Sweetners, Honey, Dates pp   BMI
# 0           355.722004                    7.130028  25.1
# 1           342.131509                    6.187895  25.1
# ...

# %%
total.columns
# Out:
# Index(['Year', 'Diabetes %', 'Malnutrition %', 'Cancer stomach %',
#        'Cancer oral %', 'Cancer oesophagus %', 'Cancer colon %',
#        'All Sugar forms pp', 'Fruits & Veggies pp',
#        'Sweetners, Honey, Dates pp', 'BMI'],
#       dtype='object')

# %%
sns.set(style="ticks")
#sns.pairplot(total[['Diabetes %', 'Malnutrition %', 'Cancer stomach %', 'Cancer oral %', 'Cancer oesophagus %',
#                    'Cancer colon %', 'All Sugar forms pp', 'Fruits & Veggies pp', 'Sweetners, Honey, Dates pp', 'BMI']])

# %%
total[['Diabetes %', 'Malnutrition %', 'Cancer stomach %', 'Cancer oral %', 'Cancer oesophagus %',
                    'Cancer colon %', 'All Sugar forms pp', 'Fruits & Veggies pp', 'Sweetners, Honey, Dates pp', 'BMI']].corr()
# Out:
#                             Diabetes %  Malnutrition %  Cancer stomach %  \
# Diabetes %                    1.000000        0.835434         -0.816305
# Malnutrition %                0.835434        1.000000         -0.916123
# Cancer stomach %             -0.816305       -0.916123          1.000000
# Cancer oral %                 0.593328        0.640491         -0.481313
# Cancer oesophagus %           0.788977        0.790505         -0.657414
# Cancer colon %                0.845455        0.774360         -0.724809
# All Sugar forms pp           -0.599961       -0.557418          0.683835
# Fruits & Veggies pp           0.369286        0.104250         -0.211043
# Sweetners, Honey, Dates pp    0.678792        0.833533         -0.771391
# BMI                           0.874674        0.945147         -0.980057
#
#                             Cancer oral %  Cancer oesophagus %  \
# Diabetes %                       0.593328             0.788977
# ...
